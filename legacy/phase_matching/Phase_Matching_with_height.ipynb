# %%
from scipy.fft import fft2, ifft2, fftshift, ifftshift
import seaborn as sns
import matplotlib.pyplot as plt
import os
import pandas as pd
import skrf as rf
import numpy as np
import re
from PIL import Image
import GSx
import DammannY as dt
import DfGen
from tqdm import tqdm

# %%
#Parâmetros
wavelength = 1064e-9  # 1064 nm
z = 380e-6           # 380 μm
dx = 520e-9          # pixel pitch
NA = 0.65            # Abertura numérica
num_iter = 60


#Geração mapa de fase polarização x
print("Gerando mapa de fase para Polarização X (Holograma)")
target_image = GSx.load_and_preprocess_image('ufabc.png', target_size=(450, 450))
phase_map_x, _ = GSx.gerchberg_saxton_angular_spectrum(
    target_image, wavelength, z, dx, NA, num_iter)

print("Mapa de fase X gerado\n")

#Geração mapa de fase polarização y
print("Gerando mapa de fase para Polarização Y (Dammann)")
phase_map_y, metrics_y, _ = dt.generate_dammann_phase_map(
    P=dx,
    wavelength=wavelength,
    supercell_pixels=45,
    n_supercells=10,
    iters_gs=400)

print("Mapa de fase Y gerado")
print("\nDimensões dos mapas de fase:")
print(f"Mapa X: {phase_map_x.shape}")
print(f"Mapa Y: {phase_map_y.shape}")
# Out:
# Gerando mapa de fase para Polarização X (Holograma)
# Iteração 10/60, Correlação: 0.9453
# Iteração 20/60, Correlação: 0.9531
# Iteração 30/60, Correlação: 0.9562
# Iteração 40/60, Correlação: 0.9580
# Iteração 50/60, Correlação: 0.9593
# Iteração 60/60, Correlação: 0.9600
# Mapa de fase X gerado
#
# Gerando mapa de fase para Polarização Y (Dammann)
# ---- Resumo Dammann ----
# Supercell: 45x45, metasurface: 450x450
# Iterações GS: 400
# Ordens propagantes M = 1513
# DE ≈ 0.999026
# RMSE uniformidade = 0.070873
# Mapa de fase Y gerado
#
# Dimensões dos mapas de fase:
# Mapa X: (450, 450)
# Mapa Y: (450, 450)

# %%
# 1. Defina o caminho para a pasta com os arquivos .ts
#    (Pode ser este ou qualquer outro caminho)
caminho_dos_dados = r"C:\Users\caval_5gfl5hy\OneDrive\Área de Trabalho\Altura_Varia"

# 2. Chame a função find_file de dentro do seu módulo DfGen
print("Iniciando a leitura dos arquivos...")
df_completo = DfGen.find_file(caminho_dos_dados)

# 3. Verifique o resultado
if df_completo is not None:
    print("\n--- DataFrame carregado com sucesso! ---")
    print(df_completo.info())
    
    # Agora você pode analisar as colunas, incluindo a 'H'
    print("\nValores únicos de altura (H) encontrados:")
    print(df_completo['H'].unique())
else:
    print("\nNenhum DataFrame foi gerado. Verifique a pasta.")
# Out:
# Iniciando a leitura dos arquivos...
# Buscando...
# Lendo arquivo: Teste_Nanopilar_1.ts (ID:1)...
# Lendo arquivo: Teste_Nanopilar_10.ts (ID:10)...
# Lendo arquivo: Teste_Nanopilar_100.ts (ID:100)...
# Lendo arquivo: Teste_Nanopilar_1000.ts (ID:1000)...
# Lendo arquivo: Teste_Nanopilar_1001.ts (ID:1001)...
# Lendo arquivo: Teste_Nanopilar_1002.ts (ID:1002)...
# Lendo arquivo: Teste_Nanopilar_1003.ts (ID:1003)...
# Lendo arquivo: Teste_Nanopilar_1004.ts (ID:1004)...
# Lendo arquivo: Teste_Nanopilar_1005.ts (ID:1005)...
# Lendo arquivo: Teste_Nanopilar_1006.ts (ID:1006)...
# Lendo arquivo: Teste_Nanopilar_1007.ts (ID:1007)...
# Lendo arquivo: Teste_Nanopilar_1008.ts (ID:1008)...
# Lendo arquivo: Teste_Nanopilar_1009.ts (ID:1009)...
# Lendo arquivo: Teste_Nanopilar_101.ts (ID:101)...
# Lendo arquivo: Teste_Nanopilar_1010.ts (ID:1010)...
# Lendo arquivo: Teste_Nanopilar_1011.ts (ID:1011)...
# Lendo arquivo: Teste_Nanopilar_1012.ts (ID:1012)...
# Lendo arquivo: Teste_Nanopilar_1013.ts (ID:1013)...
# Lendo arquivo: Teste_Nanopilar_1014.ts (ID:1014)...
# Lendo arquivo: Teste_Nanopilar_1015.ts (ID:1015)...
# Lendo arquivo: Teste_Nanopilar_1016.ts (ID:1016)...
# Lendo arquivo: Teste_Nanopilar_1017.ts (ID:1017)...
# Lendo arquivo: Teste_Nanopilar_1018.ts (ID:1018)...
# Lendo arquivo: Teste_Nanopilar_1019.ts (ID:1019)...
# Lendo arquivo: Teste_Nanopilar_102.ts (ID:102)...
# Lendo arquivo: Teste_Nanopilar_1020.ts (ID:1020)...
# Lendo arquivo: Teste_Nanopilar_1021.ts (ID:1021)...
# Lendo arquivo: Teste_Nanopilar_1022.ts (ID:1022)...
# Lendo arquivo: Teste_Nanopilar_1023.ts (ID:1023)...
# Lendo arquivo: Teste_Nanopilar_1024.ts (ID:1024)...
# Lendo arquivo: Teste_Nanopilar_1025.ts (ID:1025)...
# Lendo arquivo: Teste_Nanopilar_1026.ts (ID:1026)...
# Lendo arquivo: Teste_Nanopilar_1027.ts (ID:1027)...
# Lendo arquivo: Teste_Nanopilar_1028.ts (ID:1028)...
# Lendo arquivo: Teste_Nanopilar_1029.ts (ID:1029)...
# Lendo arquivo: Teste_Nanopilar_103.ts (ID:103)...
# Lendo arquivo: Teste_Nanopilar_1030.ts (ID:1030)...
# Lendo arquivo: Teste_Nanopilar_1031.ts (ID:1031)...
# Lendo arquivo: Teste_Nanopilar_1032.ts (ID:1032)...
# Lendo arquivo: Teste_Nanopilar_1033.ts (ID:1033)...
# Lendo arquivo: Teste_Nanopilar_1034.ts (ID:1034)...
# Lendo arquivo: Teste_Nanopilar_1035.ts (ID:1035)...
# Lendo arquivo: Teste_Nanopilar_1036.ts (ID:1036)...
# Lendo arquivo: Teste_Nanopilar_1037.ts (ID:1037)...
# Lendo arquivo: Teste_Nanopilar_1038.ts (ID:1038)...
# Lendo arquivo: Teste_Nanopilar_1039.ts (ID:1039)...
# Lendo arquivo: Teste_Nanopilar_104.ts (ID:104)...
# Lendo arquivo: Teste_Nanopilar_1040.ts (ID:1040)...
# Lendo arquivo: Teste_Nanopilar_1041.ts (ID:1041)...
# Lendo arquivo: Teste_Nanopilar_1042.ts (ID:1042)...
# Lendo arquivo: Teste_Nanopilar_1043.ts (ID:1043)...
# Lendo arquivo: Teste_Nanopilar_1044.ts (ID:1044)...
# Lendo arquivo: Teste_Nanopilar_1045.ts (ID:1045)...
# Lendo arquivo: Teste_Nanopilar_1046.ts (ID:1046)...
# Lendo arquivo: Teste_Nanopilar_1047.ts (ID:1047)...
# Lendo arquivo: Teste_Nanopilar_1048.ts (ID:1048)...
# Lendo arquivo: Teste_Nanopilar_1049.ts (ID:1049)...
# Lendo arquivo: Teste_Nanopilar_105.ts (ID:105)...
# Lendo arquivo: Teste_Nanopilar_1050.ts (ID:1050)...
# Lendo arquivo: Teste_Nanopilar_1051.ts (ID:1051)...
# Lendo arquivo: Teste_Nanopilar_1052.ts (ID:1052)...
# Lendo arquivo: Teste_Nanopilar_1053.ts (ID:1053)...
# Lendo arquivo: Teste_Nanopilar_1054.ts (ID:1054)...
# Lendo arquivo: Teste_Nanopilar_1055.ts (ID:1055)...
# Lendo arquivo: Teste_Nanopilar_1056.ts (ID:1056)...
# Lendo arquivo: Teste_Nanopilar_1057.ts (ID:1057)...
# Lendo arquivo: Teste_Nanopilar_1058.ts (ID:1058)...
# Lendo arquivo: Teste_Nanopilar_1059.ts (ID:1059)...
# Lendo arquivo: Teste_Nanopilar_106.ts (ID:106)...
# Lendo arquivo: Teste_Nanopilar_1060.ts (ID:1060)...
# Lendo arquivo: Teste_Nanopilar_1061.ts (ID:1061)...
# Lendo arquivo: Teste_Nanopilar_1062.ts (ID:1062)...
# Lendo arquivo: Teste_Nanopilar_1063.ts (ID:1063)...
# Lendo arquivo: Teste_Nanopilar_1064.ts (ID:1064)...
# Lendo arquivo: Teste_Nanopilar_1065.ts (ID:1065)...
# Lendo arquivo: Teste_Nanopilar_1066.ts (ID:1066)...
# Lendo arquivo: Teste_Nanopilar_1067.ts (ID:1067)...
# Lendo arquivo: Teste_Nanopilar_1068.ts (ID:1068)...
# Lendo arquivo: Teste_Nanopilar_1069.ts (ID:1069)...
# Lendo arquivo: Teste_Nanopilar_107.ts (ID:107)...
# Lendo arquivo: Teste_Nanopilar_1070.ts (ID:1070)...
# Lendo arquivo: Teste_Nanopilar_1071.ts (ID:1071)...
# Lendo arquivo: Teste_Nanopilar_1072.ts (ID:1072)...
# Lendo arquivo: Teste_Nanopilar_1073.ts (ID:1073)...
# Lendo arquivo: Teste_Nanopilar_1074.ts (ID:1074)...
# Lendo arquivo: Teste_Nanopilar_1075.ts (ID:1075)...
# Lendo arquivo: Teste_Nanopilar_1076.ts (ID:1076)...
# Lendo arquivo: Teste_Nanopilar_1077.ts (ID:1077)...
# Lendo arquivo: Teste_Nanopilar_1078.ts (ID:1078)...
# Lendo arquivo: Teste_Nanopilar_1079.ts (ID:1079)...
# Lendo arquivo: Teste_Nanopilar_108.ts (ID:108)...
# Lendo arquivo: Teste_Nanopilar_1080.ts (ID:1080)...
# Lendo arquivo: Teste_Nanopilar_1081.ts (ID:1081)...
# Lendo arquivo: Teste_Nanopilar_1082.ts (ID:1082)...
# Lendo arquivo: Teste_Nanopilar_1083.ts (ID:1083)...
# Lendo arquivo: Teste_Nanopilar_1084.ts (ID:1084)...
# Lendo arquivo: Teste_Nanopilar_1085.ts (ID:1085)...
# Lendo arquivo: Teste_Nanopilar_1086.ts (ID:1086)...
# Lendo arquivo: Teste_Nanopilar_1087.ts (ID:1087)...
# Lendo arquivo: Teste_Nanopilar_1088.ts (ID:1088)...
# Lendo arquivo: Teste_Nanopilar_1089.ts (ID:1089)...
# Lendo arquivo: Teste_Nanopilar_109.ts (ID:109)...
# Lendo arquivo: Teste_Nanopilar_1090.ts (ID:1090)...
# Lendo arquivo: Teste_Nanopilar_1091.ts (ID:1091)...
# Lendo arquivo: Teste_Nanopilar_1092.ts (ID:1092)...
# Lendo arquivo: Teste_Nanopilar_1093.ts (ID:1093)...
# Lendo arquivo: Teste_Nanopilar_1094.ts (ID:1094)...
# Lendo arquivo: Teste_Nanopilar_1095.ts (ID:1095)...
# Lendo arquivo: Teste_Nanopilar_1096.ts (ID:1096)...
# Lendo arquivo: Teste_Nanopilar_1097.ts (ID:1097)...
# Lendo arquivo: Teste_Nanopilar_1098.ts (ID:1098)...
# Lendo arquivo: Teste_Nanopilar_1099.ts (ID:1099)...
# Lendo arquivo: Teste_Nanopilar_11.ts (ID:11)...
# Lendo arquivo: Teste_Nanopilar_110.ts (ID:110)...
# Lendo arquivo: Teste_Nanopilar_1100.ts (ID:1100)...
# Lendo arquivo: Teste_Nanopilar_1101.ts (ID:1101)...
# Lendo arquivo: Teste_Nanopilar_1102.ts (ID:1102)...
# Lendo arquivo: Teste_Nanopilar_1103.ts (ID:1103)...
# Lendo arquivo: Teste_Nanopilar_1104.ts (ID:1104)...
# Lendo arquivo: Teste_Nanopilar_1105.ts (ID:1105)...
# Lendo arquivo: Teste_Nanopilar_1106.ts (ID:1106)...
# Lendo arquivo: Teste_Nanopilar_1107.ts (ID:1107)...
# Lendo arquivo: Teste_Nanopilar_1108.ts (ID:1108)...
# Lendo arquivo: Teste_Nanopilar_1109.ts (ID:1109)...
# Lendo arquivo: Teste_Nanopilar_111.ts (ID:111)...
# Lendo arquivo: Teste_Nanopilar_1110.ts (ID:1110)...
# Lendo arquivo: Teste_Nanopilar_1111.ts (ID:1111)...
# Lendo arquivo: Teste_Nanopilar_1112.ts (ID:1112)...
# Lendo arquivo: Teste_Nanopilar_1113.ts (ID:1113)...
# Lendo arquivo: Teste_Nanopilar_1114.ts (ID:1114)...
# Lendo arquivo: Teste_Nanopilar_1115.ts (ID:1115)...
# Lendo arquivo: Teste_Nanopilar_1116.ts (ID:1116)...
# Lendo arquivo: Teste_Nanopilar_1117.ts (ID:1117)...
# Lendo arquivo: Teste_Nanopilar_1118.ts (ID:1118)...
# Lendo arquivo: Teste_Nanopilar_1119.ts (ID:1119)...
# Lendo arquivo: Teste_Nanopilar_112.ts (ID:112)...
# Lendo arquivo: Teste_Nanopilar_1120.ts (ID:1120)...
# Lendo arquivo: Teste_Nanopilar_1121.ts (ID:1121)...
# Lendo arquivo: Teste_Nanopilar_1122.ts (ID:1122)...
# Lendo arquivo: Teste_Nanopilar_1123.ts (ID:1123)...
# Lendo arquivo: Teste_Nanopilar_1124.ts (ID:1124)...
# Lendo arquivo: Teste_Nanopilar_1125.ts (ID:1125)...
# Lendo arquivo: Teste_Nanopilar_1126.ts (ID:1126)...
# Lendo arquivo: Teste_Nanopilar_1127.ts (ID:1127)...
# Lendo arquivo: Teste_Nanopilar_1128.ts (ID:1128)...
# Lendo arquivo: Teste_Nanopilar_1129.ts (ID:1129)...
# Lendo arquivo: Teste_Nanopilar_113.ts (ID:113)...
# Lendo arquivo: Teste_Nanopilar_1130.ts (ID:1130)...
# Lendo arquivo: Teste_Nanopilar_1131.ts (ID:1131)...
# Lendo arquivo: Teste_Nanopilar_1132.ts (ID:1132)...
# Lendo arquivo: Teste_Nanopilar_1133.ts (ID:1133)...
# Lendo arquivo: Teste_Nanopilar_1134.ts (ID:1134)...
# Lendo arquivo: Teste_Nanopilar_1135.ts (ID:1135)...
# Lendo arquivo: Teste_Nanopilar_1136.ts (ID:1136)...
# Lendo arquivo: Teste_Nanopilar_1137.ts (ID:1137)...
# Lendo arquivo: Teste_Nanopilar_1138.ts (ID:1138)...
# Lendo arquivo: Teste_Nanopilar_1139.ts (ID:1139)...
# Lendo arquivo: Teste_Nanopilar_114.ts (ID:114)...
# Lendo arquivo: Teste_Nanopilar_1140.ts (ID:1140)...
# Lendo arquivo: Teste_Nanopilar_1141.ts (ID:1141)...
# Lendo arquivo: Teste_Nanopilar_1142.ts (ID:1142)...
# Lendo arquivo: Teste_Nanopilar_1143.ts (ID:1143)...
# Lendo arquivo: Teste_Nanopilar_1144.ts (ID:1144)...
# Lendo arquivo: Teste_Nanopilar_1145.ts (ID:1145)...
# Lendo arquivo: Teste_Nanopilar_1146.ts (ID:1146)...
# Lendo arquivo: Teste_Nanopilar_1147.ts (ID:1147)...
# Lendo arquivo: Teste_Nanopilar_1148.ts (ID:1148)...
# Lendo arquivo: Teste_Nanopilar_1149.ts (ID:1149)...
# Lendo arquivo: Teste_Nanopilar_115.ts (ID:115)...
# Lendo arquivo: Teste_Nanopilar_1150.ts (ID:1150)...
# Lendo arquivo: Teste_Nanopilar_1151.ts (ID:1151)...
# Lendo arquivo: Teste_Nanopilar_1152.ts (ID:1152)...
# Lendo arquivo: Teste_Nanopilar_1153.ts (ID:1153)...
# Lendo arquivo: Teste_Nanopilar_1154.ts (ID:1154)...
# Lendo arquivo: Teste_Nanopilar_1155.ts (ID:1155)...
# Lendo arquivo: Teste_Nanopilar_1156.ts (ID:1156)...
# Lendo arquivo: Teste_Nanopilar_1157.ts (ID:1157)...
# Lendo arquivo: Teste_Nanopilar_1158.ts (ID:1158)...
# Lendo arquivo: Teste_Nanopilar_1159.ts (ID:1159)...
# Lendo arquivo: Teste_Nanopilar_116.ts (ID:116)...
# Lendo arquivo: Teste_Nanopilar_1160.ts (ID:1160)...
# Lendo arquivo: Teste_Nanopilar_1161.ts (ID:1161)...
# Lendo arquivo: Teste_Nanopilar_1162.ts (ID:1162)...
# Lendo arquivo: Teste_Nanopilar_1163.ts (ID:1163)...
# Lendo arquivo: Teste_Nanopilar_1164.ts (ID:1164)...
# Lendo arquivo: Teste_Nanopilar_1165.ts (ID:1165)...
# Lendo arquivo: Teste_Nanopilar_1166.ts (ID:1166)...
# Lendo arquivo: Teste_Nanopilar_1167.ts (ID:1167)...
# Lendo arquivo: Teste_Nanopilar_1168.ts (ID:1168)...
# Lendo arquivo: Teste_Nanopilar_1169.ts (ID:1169)...
# Lendo arquivo: Teste_Nanopilar_117.ts (ID:117)...
# Lendo arquivo: Teste_Nanopilar_1170.ts (ID:1170)...
# Lendo arquivo: Teste_Nanopilar_1171.ts (ID:1171)...
# Lendo arquivo: Teste_Nanopilar_1172.ts (ID:1172)...
# Lendo arquivo: Teste_Nanopilar_1173.ts (ID:1173)...
# Lendo arquivo: Teste_Nanopilar_1174.ts (ID:1174)...
# Lendo arquivo: Teste_Nanopilar_1175.ts (ID:1175)...
# Lendo arquivo: Teste_Nanopilar_118.ts (ID:118)...
# Lendo arquivo: Teste_Nanopilar_119.ts (ID:119)...
# Lendo arquivo: Teste_Nanopilar_12.ts (ID:12)...
# Lendo arquivo: Teste_Nanopilar_120.ts (ID:120)...
# Lendo arquivo: Teste_Nanopilar_121.ts (ID:121)...
# Lendo arquivo: Teste_Nanopilar_122.ts (ID:122)...
# Lendo arquivo: Teste_Nanopilar_123.ts (ID:123)...
# Lendo arquivo: Teste_Nanopilar_124.ts (ID:124)...
# Lendo arquivo: Teste_Nanopilar_125.ts (ID:125)...
# Lendo arquivo: Teste_Nanopilar_126.ts (ID:126)...
# Lendo arquivo: Teste_Nanopilar_127.ts (ID:127)...
# Lendo arquivo: Teste_Nanopilar_128.ts (ID:128)...
# Lendo arquivo: Teste_Nanopilar_129.ts (ID:129)...
# Lendo arquivo: Teste_Nanopilar_13.ts (ID:13)...
# Lendo arquivo: Teste_Nanopilar_130.ts (ID:130)...
# Lendo arquivo: Teste_Nanopilar_131.ts (ID:131)...
# Lendo arquivo: Teste_Nanopilar_132.ts (ID:132)...
# Lendo arquivo: Teste_Nanopilar_133.ts (ID:133)...
# Lendo arquivo: Teste_Nanopilar_134.ts (ID:134)...
# Lendo arquivo: Teste_Nanopilar_135.ts (ID:135)...
# Lendo arquivo: Teste_Nanopilar_136.ts (ID:136)...
# Lendo arquivo: Teste_Nanopilar_137.ts (ID:137)...
# Lendo arquivo: Teste_Nanopilar_138.ts (ID:138)...
# Lendo arquivo: Teste_Nanopilar_139.ts (ID:139)...
# Lendo arquivo: Teste_Nanopilar_14.ts (ID:14)...
# Lendo arquivo: Teste_Nanopilar_140.ts (ID:140)...
# Lendo arquivo: Teste_Nanopilar_141.ts (ID:141)...
# Lendo arquivo: Teste_Nanopilar_142.ts (ID:142)...
# Lendo arquivo: Teste_Nanopilar_143.ts (ID:143)...
# Lendo arquivo: Teste_Nanopilar_144.ts (ID:144)...
# Lendo arquivo: Teste_Nanopilar_145.ts (ID:145)...
# Lendo arquivo: Teste_Nanopilar_146.ts (ID:146)...
# Lendo arquivo: Teste_Nanopilar_147.ts (ID:147)...
# Lendo arquivo: Teste_Nanopilar_148.ts (ID:148)...
# Lendo arquivo: Teste_Nanopilar_149.ts (ID:149)...
# Lendo arquivo: Teste_Nanopilar_15.ts (ID:15)...
# Lendo arquivo: Teste_Nanopilar_150.ts (ID:150)...
# Lendo arquivo: Teste_Nanopilar_151.ts (ID:151)...
# Lendo arquivo: Teste_Nanopilar_152.ts (ID:152)...
# Lendo arquivo: Teste_Nanopilar_153.ts (ID:153)...
# Lendo arquivo: Teste_Nanopilar_154.ts (ID:154)...
# Lendo arquivo: Teste_Nanopilar_155.ts (ID:155)...
# Lendo arquivo: Teste_Nanopilar_156.ts (ID:156)...
# Lendo arquivo: Teste_Nanopilar_157.ts (ID:157)...
# Lendo arquivo: Teste_Nanopilar_158.ts (ID:158)...
# Lendo arquivo: Teste_Nanopilar_159.ts (ID:159)...
# Lendo arquivo: Teste_Nanopilar_16.ts (ID:16)...
# Lendo arquivo: Teste_Nanopilar_160.ts (ID:160)...
# Lendo arquivo: Teste_Nanopilar_161.ts (ID:161)...
# Lendo arquivo: Teste_Nanopilar_162.ts (ID:162)...
# Lendo arquivo: Teste_Nanopilar_163.ts (ID:163)...
# Lendo arquivo: Teste_Nanopilar_164.ts (ID:164)...
# Lendo arquivo: Teste_Nanopilar_165.ts (ID:165)...
# Lendo arquivo: Teste_Nanopilar_166.ts (ID:166)...
# Lendo arquivo: Teste_Nanopilar_167.ts (ID:167)...
# Lendo arquivo: Teste_Nanopilar_168.ts (ID:168)...
# Lendo arquivo: Teste_Nanopilar_169.ts (ID:169)...
# Lendo arquivo: Teste_Nanopilar_17.ts (ID:17)...
# Lendo arquivo: Teste_Nanopilar_170.ts (ID:170)...
# Lendo arquivo: Teste_Nanopilar_171.ts (ID:171)...
# Lendo arquivo: Teste_Nanopilar_172.ts (ID:172)...
# Lendo arquivo: Teste_Nanopilar_173.ts (ID:173)...
# Lendo arquivo: Teste_Nanopilar_174.ts (ID:174)...
# Lendo arquivo: Teste_Nanopilar_175.ts (ID:175)...
# Lendo arquivo: Teste_Nanopilar_176.ts (ID:176)...
# Lendo arquivo: Teste_Nanopilar_177.ts (ID:177)...
# Lendo arquivo: Teste_Nanopilar_178.ts (ID:178)...
# Lendo arquivo: Teste_Nanopilar_179.ts (ID:179)...
# Lendo arquivo: Teste_Nanopilar_18.ts (ID:18)...
# Lendo arquivo: Teste_Nanopilar_180.ts (ID:180)...
# Lendo arquivo: Teste_Nanopilar_181.ts (ID:181)...
# Lendo arquivo: Teste_Nanopilar_182.ts (ID:182)...
# Lendo arquivo: Teste_Nanopilar_183.ts (ID:183)...
# Lendo arquivo: Teste_Nanopilar_184.ts (ID:184)...
# Lendo arquivo: Teste_Nanopilar_185.ts (ID:185)...
# Lendo arquivo: Teste_Nanopilar_186.ts (ID:186)...
# Lendo arquivo: Teste_Nanopilar_187.ts (ID:187)...
# Lendo arquivo: Teste_Nanopilar_188.ts (ID:188)...
# Lendo arquivo: Teste_Nanopilar_189.ts (ID:189)...
# Lendo arquivo: Teste_Nanopilar_19.ts (ID:19)...
# Lendo arquivo: Teste_Nanopilar_190.ts (ID:190)...
# Lendo arquivo: Teste_Nanopilar_191.ts (ID:191)...
# Lendo arquivo: Teste_Nanopilar_192.ts (ID:192)...
# Lendo arquivo: Teste_Nanopilar_193.ts (ID:193)...
# Lendo arquivo: Teste_Nanopilar_194.ts (ID:194)...
# Lendo arquivo: Teste_Nanopilar_195.ts (ID:195)...
# Lendo arquivo: Teste_Nanopilar_196.ts (ID:196)...
# Lendo arquivo: Teste_Nanopilar_197.ts (ID:197)...
# Lendo arquivo: Teste_Nanopilar_198.ts (ID:198)...
# Lendo arquivo: Teste_Nanopilar_199.ts (ID:199)...
# Lendo arquivo: Teste_Nanopilar_2.ts (ID:2)...
# Lendo arquivo: Teste_Nanopilar_20.ts (ID:20)...
# Lendo arquivo: Teste_Nanopilar_200.ts (ID:200)...
# Lendo arquivo: Teste_Nanopilar_201.ts (ID:201)...
# Lendo arquivo: Teste_Nanopilar_202.ts (ID:202)...
# Lendo arquivo: Teste_Nanopilar_203.ts (ID:203)...
# Lendo arquivo: Teste_Nanopilar_204.ts (ID:204)...
# Lendo arquivo: Teste_Nanopilar_205.ts (ID:205)...
# Lendo arquivo: Teste_Nanopilar_206.ts (ID:206)...
# Lendo arquivo: Teste_Nanopilar_207.ts (ID:207)...
# Lendo arquivo: Teste_Nanopilar_208.ts (ID:208)...
# Lendo arquivo: Teste_Nanopilar_209.ts (ID:209)...
# Lendo arquivo: Teste_Nanopilar_21.ts (ID:21)...
# Lendo arquivo: Teste_Nanopilar_210.ts (ID:210)...
# Lendo arquivo: Teste_Nanopilar_211.ts (ID:211)...
# Lendo arquivo: Teste_Nanopilar_212.ts (ID:212)...
# Lendo arquivo: Teste_Nanopilar_213.ts (ID:213)...
# Lendo arquivo: Teste_Nanopilar_214.ts (ID:214)...
# Lendo arquivo: Teste_Nanopilar_215.ts (ID:215)...
# Lendo arquivo: Teste_Nanopilar_216.ts (ID:216)...
# Lendo arquivo: Teste_Nanopilar_217.ts (ID:217)...
# Lendo arquivo: Teste_Nanopilar_218.ts (ID:218)...
# Lendo arquivo: Teste_Nanopilar_219.ts (ID:219)...
# Lendo arquivo: Teste_Nanopilar_22.ts (ID:22)...
# Lendo arquivo: Teste_Nanopilar_220.ts (ID:220)...
# Lendo arquivo: Teste_Nanopilar_221.ts (ID:221)...
# Lendo arquivo: Teste_Nanopilar_222.ts (ID:222)...
# Lendo arquivo: Teste_Nanopilar_223.ts (ID:223)...
# Lendo arquivo: Teste_Nanopilar_224.ts (ID:224)...
# Lendo arquivo: Teste_Nanopilar_225.ts (ID:225)...
# Lendo arquivo: Teste_Nanopilar_226.ts (ID:226)...
# Lendo arquivo: Teste_Nanopilar_227.ts (ID:227)...
# Lendo arquivo: Teste_Nanopilar_228.ts (ID:228)...
# Lendo arquivo: Teste_Nanopilar_229.ts (ID:229)...
# Lendo arquivo: Teste_Nanopilar_23.ts (ID:23)...
# Lendo arquivo: Teste_Nanopilar_230.ts (ID:230)...
# Lendo arquivo: Teste_Nanopilar_231.ts (ID:231)...
# Lendo arquivo: Teste_Nanopilar_232.ts (ID:232)...
# Lendo arquivo: Teste_Nanopilar_233.ts (ID:233)...
# Lendo arquivo: Teste_Nanopilar_234.ts (ID:234)...
# Lendo arquivo: Teste_Nanopilar_235.ts (ID:235)...
# Lendo arquivo: Teste_Nanopilar_236.ts (ID:236)...
# Lendo arquivo: Teste_Nanopilar_237.ts (ID:237)...
# Lendo arquivo: Teste_Nanopilar_238.ts (ID:238)...
# Lendo arquivo: Teste_Nanopilar_239.ts (ID:239)...
# Lendo arquivo: Teste_Nanopilar_24.ts (ID:24)...
# Lendo arquivo: Teste_Nanopilar_240.ts (ID:240)...
# Lendo arquivo: Teste_Nanopilar_241.ts (ID:241)...
# Lendo arquivo: Teste_Nanopilar_242.ts (ID:242)...
# Lendo arquivo: Teste_Nanopilar_243.ts (ID:243)...
# Lendo arquivo: Teste_Nanopilar_244.ts (ID:244)...
# Lendo arquivo: Teste_Nanopilar_245.ts (ID:245)...
# Lendo arquivo: Teste_Nanopilar_246.ts (ID:246)...
# Lendo arquivo: Teste_Nanopilar_247.ts (ID:247)...
# Lendo arquivo: Teste_Nanopilar_248.ts (ID:248)...
# Lendo arquivo: Teste_Nanopilar_249.ts (ID:249)...
# Lendo arquivo: Teste_Nanopilar_25.ts (ID:25)...
# Lendo arquivo: Teste_Nanopilar_250.ts (ID:250)...
# Lendo arquivo: Teste_Nanopilar_251.ts (ID:251)...
# Lendo arquivo: Teste_Nanopilar_252.ts (ID:252)...
# Lendo arquivo: Teste_Nanopilar_253.ts (ID:253)...
# Lendo arquivo: Teste_Nanopilar_254.ts (ID:254)...
# Lendo arquivo: Teste_Nanopilar_255.ts (ID:255)...
# Lendo arquivo: Teste_Nanopilar_256.ts (ID:256)...
# Lendo arquivo: Teste_Nanopilar_257.ts (ID:257)...
# Lendo arquivo: Teste_Nanopilar_258.ts (ID:258)...
# Lendo arquivo: Teste_Nanopilar_259.ts (ID:259)...
# Lendo arquivo: Teste_Nanopilar_26.ts (ID:26)...
# Lendo arquivo: Teste_Nanopilar_260.ts (ID:260)...
# Lendo arquivo: Teste_Nanopilar_261.ts (ID:261)...
# Lendo arquivo: Teste_Nanopilar_262.ts (ID:262)...
# Lendo arquivo: Teste_Nanopilar_263.ts (ID:263)...
# Lendo arquivo: Teste_Nanopilar_264.ts (ID:264)...
# Lendo arquivo: Teste_Nanopilar_265.ts (ID:265)...
# Lendo arquivo: Teste_Nanopilar_266.ts (ID:266)...
# Lendo arquivo: Teste_Nanopilar_267.ts (ID:267)...
# Lendo arquivo: Teste_Nanopilar_268.ts (ID:268)...
# Lendo arquivo: Teste_Nanopilar_269.ts (ID:269)...
# Lendo arquivo: Teste_Nanopilar_27.ts (ID:27)...
# Lendo arquivo: Teste_Nanopilar_270.ts (ID:270)...
# Lendo arquivo: Teste_Nanopilar_271.ts (ID:271)...
# Lendo arquivo: Teste_Nanopilar_272.ts (ID:272)...
# Lendo arquivo: Teste_Nanopilar_273.ts (ID:273)...
# Lendo arquivo: Teste_Nanopilar_274.ts (ID:274)...
# Lendo arquivo: Teste_Nanopilar_275.ts (ID:275)...
# Lendo arquivo: Teste_Nanopilar_276.ts (ID:276)...
# Lendo arquivo: Teste_Nanopilar_277.ts (ID:277)...
# Lendo arquivo: Teste_Nanopilar_278.ts (ID:278)...
# Lendo arquivo: Teste_Nanopilar_279.ts (ID:279)...
# Lendo arquivo: Teste_Nanopilar_28.ts (ID:28)...
# Lendo arquivo: Teste_Nanopilar_280.ts (ID:280)...
# Lendo arquivo: Teste_Nanopilar_281.ts (ID:281)...
# Lendo arquivo: Teste_Nanopilar_282.ts (ID:282)...
# Lendo arquivo: Teste_Nanopilar_283.ts (ID:283)...
# Lendo arquivo: Teste_Nanopilar_284.ts (ID:284)...
# Lendo arquivo: Teste_Nanopilar_285.ts (ID:285)...
# Lendo arquivo: Teste_Nanopilar_286.ts (ID:286)...
# Lendo arquivo: Teste_Nanopilar_287.ts (ID:287)...
# Lendo arquivo: Teste_Nanopilar_288.ts (ID:288)...
# Lendo arquivo: Teste_Nanopilar_289.ts (ID:289)...
# Lendo arquivo: Teste_Nanopilar_29.ts (ID:29)...
# Lendo arquivo: Teste_Nanopilar_290.ts (ID:290)...
# Lendo arquivo: Teste_Nanopilar_291.ts (ID:291)...
# Lendo arquivo: Teste_Nanopilar_292.ts (ID:292)...
# Lendo arquivo: Teste_Nanopilar_293.ts (ID:293)...
# Lendo arquivo: Teste_Nanopilar_294.ts (ID:294)...
# Lendo arquivo: Teste_Nanopilar_295.ts (ID:295)...
# Lendo arquivo: Teste_Nanopilar_296.ts (ID:296)...
# Lendo arquivo: Teste_Nanopilar_297.ts (ID:297)...
# Lendo arquivo: Teste_Nanopilar_298.ts (ID:298)...
# Lendo arquivo: Teste_Nanopilar_299.ts (ID:299)...
# Lendo arquivo: Teste_Nanopilar_3.ts (ID:3)...
# Lendo arquivo: Teste_Nanopilar_30.ts (ID:30)...
# Lendo arquivo: Teste_Nanopilar_300.ts (ID:300)...
# Lendo arquivo: Teste_Nanopilar_301.ts (ID:301)...
# Lendo arquivo: Teste_Nanopilar_302.ts (ID:302)...
# Lendo arquivo: Teste_Nanopilar_303.ts (ID:303)...
# Lendo arquivo: Teste_Nanopilar_304.ts (ID:304)...
# Lendo arquivo: Teste_Nanopilar_305.ts (ID:305)...
# Lendo arquivo: Teste_Nanopilar_306.ts (ID:306)...
# Lendo arquivo: Teste_Nanopilar_307.ts (ID:307)...
# Lendo arquivo: Teste_Nanopilar_308.ts (ID:308)...
# Lendo arquivo: Teste_Nanopilar_309.ts (ID:309)...
# Lendo arquivo: Teste_Nanopilar_31.ts (ID:31)...
# Lendo arquivo: Teste_Nanopilar_310.ts (ID:310)...
# Lendo arquivo: Teste_Nanopilar_311.ts (ID:311)...
# Lendo arquivo: Teste_Nanopilar_312.ts (ID:312)...
# Lendo arquivo: Teste_Nanopilar_313.ts (ID:313)...
# Lendo arquivo: Teste_Nanopilar_314.ts (ID:314)...
# Lendo arquivo: Teste_Nanopilar_315.ts (ID:315)...
# Lendo arquivo: Teste_Nanopilar_316.ts (ID:316)...
# Lendo arquivo: Teste_Nanopilar_317.ts (ID:317)...
# Lendo arquivo: Teste_Nanopilar_318.ts (ID:318)...
# Lendo arquivo: Teste_Nanopilar_319.ts (ID:319)...
# Lendo arquivo: Teste_Nanopilar_32.ts (ID:32)...
# Lendo arquivo: Teste_Nanopilar_320.ts (ID:320)...
# Lendo arquivo: Teste_Nanopilar_321.ts (ID:321)...
# Lendo arquivo: Teste_Nanopilar_322.ts (ID:322)...
# Lendo arquivo: Teste_Nanopilar_323.ts (ID:323)...
# Lendo arquivo: Teste_Nanopilar_324.ts (ID:324)...
# Lendo arquivo: Teste_Nanopilar_325.ts (ID:325)...
# Lendo arquivo: Teste_Nanopilar_326.ts (ID:326)...
# Lendo arquivo: Teste_Nanopilar_327.ts (ID:327)...
# Lendo arquivo: Teste_Nanopilar_328.ts (ID:328)...
# Lendo arquivo: Teste_Nanopilar_329.ts (ID:329)...
# Lendo arquivo: Teste_Nanopilar_33.ts (ID:33)...
# Lendo arquivo: Teste_Nanopilar_330.ts (ID:330)...
# Lendo arquivo: Teste_Nanopilar_331.ts (ID:331)...
# Lendo arquivo: Teste_Nanopilar_332.ts (ID:332)...
# Lendo arquivo: Teste_Nanopilar_333.ts (ID:333)...
# Lendo arquivo: Teste_Nanopilar_334.ts (ID:334)...
# Lendo arquivo: Teste_Nanopilar_335.ts (ID:335)...
# Lendo arquivo: Teste_Nanopilar_336.ts (ID:336)...
# Lendo arquivo: Teste_Nanopilar_337.ts (ID:337)...
# Lendo arquivo: Teste_Nanopilar_338.ts (ID:338)...
# Lendo arquivo: Teste_Nanopilar_339.ts (ID:339)...
# Lendo arquivo: Teste_Nanopilar_34.ts (ID:34)...
# Lendo arquivo: Teste_Nanopilar_340.ts (ID:340)...
# Lendo arquivo: Teste_Nanopilar_341.ts (ID:341)...
# Lendo arquivo: Teste_Nanopilar_342.ts (ID:342)...
# Lendo arquivo: Teste_Nanopilar_343.ts (ID:343)...
# Lendo arquivo: Teste_Nanopilar_344.ts (ID:344)...
# Lendo arquivo: Teste_Nanopilar_345.ts (ID:345)...
# Lendo arquivo: Teste_Nanopilar_346.ts (ID:346)...
# Lendo arquivo: Teste_Nanopilar_347.ts (ID:347)...
# Lendo arquivo: Teste_Nanopilar_348.ts (ID:348)...
# Lendo arquivo: Teste_Nanopilar_349.ts (ID:349)...
# Lendo arquivo: Teste_Nanopilar_35.ts (ID:35)...
# Lendo arquivo: Teste_Nanopilar_350.ts (ID:350)...
# Lendo arquivo: Teste_Nanopilar_351.ts (ID:351)...
# Lendo arquivo: Teste_Nanopilar_352.ts (ID:352)...
# Lendo arquivo: Teste_Nanopilar_353.ts (ID:353)...
# Lendo arquivo: Teste_Nanopilar_354.ts (ID:354)...
# Lendo arquivo: Teste_Nanopilar_355.ts (ID:355)...
# Lendo arquivo: Teste_Nanopilar_356.ts (ID:356)...
# Lendo arquivo: Teste_Nanopilar_357.ts (ID:357)...
# Lendo arquivo: Teste_Nanopilar_358.ts (ID:358)...
# Lendo arquivo: Teste_Nanopilar_359.ts (ID:359)...
# Lendo arquivo: Teste_Nanopilar_36.ts (ID:36)...
# Lendo arquivo: Teste_Nanopilar_360.ts (ID:360)...
# Lendo arquivo: Teste_Nanopilar_361.ts (ID:361)...
# Lendo arquivo: Teste_Nanopilar_362.ts (ID:362)...
# Lendo arquivo: Teste_Nanopilar_363.ts (ID:363)...
# Lendo arquivo: Teste_Nanopilar_364.ts (ID:364)...
# Lendo arquivo: Teste_Nanopilar_365.ts (ID:365)...
# Lendo arquivo: Teste_Nanopilar_366.ts (ID:366)...
# Lendo arquivo: Teste_Nanopilar_367.ts (ID:367)...
# Lendo arquivo: Teste_Nanopilar_368.ts (ID:368)...
# Lendo arquivo: Teste_Nanopilar_369.ts (ID:369)...
# Lendo arquivo: Teste_Nanopilar_37.ts (ID:37)...
# Lendo arquivo: Teste_Nanopilar_370.ts (ID:370)...
# Lendo arquivo: Teste_Nanopilar_371.ts (ID:371)...
# Lendo arquivo: Teste_Nanopilar_372.ts (ID:372)...
# Lendo arquivo: Teste_Nanopilar_373.ts (ID:373)...
# Lendo arquivo: Teste_Nanopilar_374.ts (ID:374)...
# Lendo arquivo: Teste_Nanopilar_375.ts (ID:375)...
# Lendo arquivo: Teste_Nanopilar_376.ts (ID:376)...
# Lendo arquivo: Teste_Nanopilar_377.ts (ID:377)...
# Lendo arquivo: Teste_Nanopilar_378.ts (ID:378)...
# Lendo arquivo: Teste_Nanopilar_379.ts (ID:379)...
# Lendo arquivo: Teste_Nanopilar_38.ts (ID:38)...
# Lendo arquivo: Teste_Nanopilar_380.ts (ID:380)...
# Lendo arquivo: Teste_Nanopilar_381.ts (ID:381)...
# Lendo arquivo: Teste_Nanopilar_382.ts (ID:382)...
# Lendo arquivo: Teste_Nanopilar_383.ts (ID:383)...
# Lendo arquivo: Teste_Nanopilar_384.ts (ID:384)...
# Lendo arquivo: Teste_Nanopilar_385.ts (ID:385)...
# Lendo arquivo: Teste_Nanopilar_386.ts (ID:386)...
# Lendo arquivo: Teste_Nanopilar_387.ts (ID:387)...
# Lendo arquivo: Teste_Nanopilar_388.ts (ID:388)...
# Lendo arquivo: Teste_Nanopilar_389.ts (ID:389)...
# Lendo arquivo: Teste_Nanopilar_39.ts (ID:39)...
# Lendo arquivo: Teste_Nanopilar_390.ts (ID:390)...
# Lendo arquivo: Teste_Nanopilar_391.ts (ID:391)...
# Lendo arquivo: Teste_Nanopilar_392.ts (ID:392)...
# Lendo arquivo: Teste_Nanopilar_393.ts (ID:393)...
# Lendo arquivo: Teste_Nanopilar_394.ts (ID:394)...
# Lendo arquivo: Teste_Nanopilar_395.ts (ID:395)...
# Lendo arquivo: Teste_Nanopilar_396.ts (ID:396)...
# Lendo arquivo: Teste_Nanopilar_397.ts (ID:397)...
# Lendo arquivo: Teste_Nanopilar_398.ts (ID:398)...
# Lendo arquivo: Teste_Nanopilar_399.ts (ID:399)...
# Lendo arquivo: Teste_Nanopilar_4.ts (ID:4)...
# Lendo arquivo: Teste_Nanopilar_40.ts (ID:40)...
# Lendo arquivo: Teste_Nanopilar_400.ts (ID:400)...
# Lendo arquivo: Teste_Nanopilar_401.ts (ID:401)...
# Lendo arquivo: Teste_Nanopilar_402.ts (ID:402)...
# Lendo arquivo: Teste_Nanopilar_403.ts (ID:403)...
# Lendo arquivo: Teste_Nanopilar_404.ts (ID:404)...
# Lendo arquivo: Teste_Nanopilar_405.ts (ID:405)...
# Lendo arquivo: Teste_Nanopilar_406.ts (ID:406)...
# Lendo arquivo: Teste_Nanopilar_407.ts (ID:407)...
# Lendo arquivo: Teste_Nanopilar_408.ts (ID:408)...
# Lendo arquivo: Teste_Nanopilar_409.ts (ID:409)...
# Lendo arquivo: Teste_Nanopilar_41.ts (ID:41)...
# Lendo arquivo: Teste_Nanopilar_410.ts (ID:410)...
# Lendo arquivo: Teste_Nanopilar_411.ts (ID:411)...
# Lendo arquivo: Teste_Nanopilar_412.ts (ID:412)...
# Lendo arquivo: Teste_Nanopilar_413.ts (ID:413)...
# Lendo arquivo: Teste_Nanopilar_414.ts (ID:414)...
# Lendo arquivo: Teste_Nanopilar_415.ts (ID:415)...
# Lendo arquivo: Teste_Nanopilar_416.ts (ID:416)...
# Lendo arquivo: Teste_Nanopilar_417.ts (ID:417)...
# Lendo arquivo: Teste_Nanopilar_418.ts (ID:418)...
# Lendo arquivo: Teste_Nanopilar_419.ts (ID:419)...
# Lendo arquivo: Teste_Nanopilar_42.ts (ID:42)...
# Lendo arquivo: Teste_Nanopilar_420.ts (ID:420)...
# Lendo arquivo: Teste_Nanopilar_421.ts (ID:421)...
# Lendo arquivo: Teste_Nanopilar_422.ts (ID:422)...
# Lendo arquivo: Teste_Nanopilar_423.ts (ID:423)...
# Lendo arquivo: Teste_Nanopilar_424.ts (ID:424)...
# Lendo arquivo: Teste_Nanopilar_425.ts (ID:425)...
# Lendo arquivo: Teste_Nanopilar_426.ts (ID:426)...
# Lendo arquivo: Teste_Nanopilar_427.ts (ID:427)...
# Lendo arquivo: Teste_Nanopilar_428.ts (ID:428)...
# Lendo arquivo: Teste_Nanopilar_429.ts (ID:429)...
# Lendo arquivo: Teste_Nanopilar_43.ts (ID:43)...
# Lendo arquivo: Teste_Nanopilar_430.ts (ID:430)...
# Lendo arquivo: Teste_Nanopilar_431.ts (ID:431)...
# Lendo arquivo: Teste_Nanopilar_432.ts (ID:432)...
# Lendo arquivo: Teste_Nanopilar_433.ts (ID:433)...
# Lendo arquivo: Teste_Nanopilar_434.ts (ID:434)...
# Lendo arquivo: Teste_Nanopilar_435.ts (ID:435)...
# Lendo arquivo: Teste_Nanopilar_436.ts (ID:436)...
# Lendo arquivo: Teste_Nanopilar_437.ts (ID:437)...
# Lendo arquivo: Teste_Nanopilar_438.ts (ID:438)...
# Lendo arquivo: Teste_Nanopilar_439.ts (ID:439)...
# Lendo arquivo: Teste_Nanopilar_44.ts (ID:44)...
# Lendo arquivo: Teste_Nanopilar_440.ts (ID:440)...
# Lendo arquivo: Teste_Nanopilar_441.ts (ID:441)...
# Lendo arquivo: Teste_Nanopilar_442.ts (ID:442)...
# Lendo arquivo: Teste_Nanopilar_443.ts (ID:443)...
# Lendo arquivo: Teste_Nanopilar_444.ts (ID:444)...
# Lendo arquivo: Teste_Nanopilar_445.ts (ID:445)...
# Lendo arquivo: Teste_Nanopilar_446.ts (ID:446)...
# Lendo arquivo: Teste_Nanopilar_447.ts (ID:447)...
# Lendo arquivo: Teste_Nanopilar_448.ts (ID:448)...
# Lendo arquivo: Teste_Nanopilar_449.ts (ID:449)...
# Lendo arquivo: Teste_Nanopilar_45.ts (ID:45)...
# Lendo arquivo: Teste_Nanopilar_450.ts (ID:450)...
# Lendo arquivo: Teste_Nanopilar_451.ts (ID:451)...
# Lendo arquivo: Teste_Nanopilar_452.ts (ID:452)...
# Lendo arquivo: Teste_Nanopilar_453.ts (ID:453)...
# Lendo arquivo: Teste_Nanopilar_454.ts (ID:454)...
# Lendo arquivo: Teste_Nanopilar_455.ts (ID:455)...
# Lendo arquivo: Teste_Nanopilar_456.ts (ID:456)...
# Lendo arquivo: Teste_Nanopilar_457.ts (ID:457)...
# Lendo arquivo: Teste_Nanopilar_458.ts (ID:458)...
# Lendo arquivo: Teste_Nanopilar_459.ts (ID:459)...
# Lendo arquivo: Teste_Nanopilar_46.ts (ID:46)...
# Lendo arquivo: Teste_Nanopilar_460.ts (ID:460)...
# Lendo arquivo: Teste_Nanopilar_461.ts (ID:461)...
# Lendo arquivo: Teste_Nanopilar_462.ts (ID:462)...
# Lendo arquivo: Teste_Nanopilar_463.ts (ID:463)...
# Lendo arquivo: Teste_Nanopilar_464.ts (ID:464)...
# Lendo arquivo: Teste_Nanopilar_465.ts (ID:465)...
# Lendo arquivo: Teste_Nanopilar_466.ts (ID:466)...
# Lendo arquivo: Teste_Nanopilar_467.ts (ID:467)...
# Lendo arquivo: Teste_Nanopilar_468.ts (ID:468)...
# Lendo arquivo: Teste_Nanopilar_469.ts (ID:469)...
# Lendo arquivo: Teste_Nanopilar_47.ts (ID:47)...
# Lendo arquivo: Teste_Nanopilar_470.ts (ID:470)...
# Lendo arquivo: Teste_Nanopilar_471.ts (ID:471)...
# Lendo arquivo: Teste_Nanopilar_472.ts (ID:472)...
# Lendo arquivo: Teste_Nanopilar_473.ts (ID:473)...
# Lendo arquivo: Teste_Nanopilar_474.ts (ID:474)...
# Lendo arquivo: Teste_Nanopilar_475.ts (ID:475)...
# Lendo arquivo: Teste_Nanopilar_476.ts (ID:476)...
# Lendo arquivo: Teste_Nanopilar_477.ts (ID:477)...
# Lendo arquivo: Teste_Nanopilar_478.ts (ID:478)...
# Lendo arquivo: Teste_Nanopilar_479.ts (ID:479)...
# Lendo arquivo: Teste_Nanopilar_48.ts (ID:48)...
# Lendo arquivo: Teste_Nanopilar_480.ts (ID:480)...
# Lendo arquivo: Teste_Nanopilar_481.ts (ID:481)...
# Lendo arquivo: Teste_Nanopilar_482.ts (ID:482)...
# Lendo arquivo: Teste_Nanopilar_483.ts (ID:483)...
# Lendo arquivo: Teste_Nanopilar_484.ts (ID:484)...
# Lendo arquivo: Teste_Nanopilar_485.ts (ID:485)...
# Lendo arquivo: Teste_Nanopilar_486.ts (ID:486)...
# Lendo arquivo: Teste_Nanopilar_487.ts (ID:487)...
# Lendo arquivo: Teste_Nanopilar_488.ts (ID:488)...
# Lendo arquivo: Teste_Nanopilar_489.ts (ID:489)...
# Lendo arquivo: Teste_Nanopilar_49.ts (ID:49)...
# Lendo arquivo: Teste_Nanopilar_490.ts (ID:490)...
# Lendo arquivo: Teste_Nanopilar_491.ts (ID:491)...
# Lendo arquivo: Teste_Nanopilar_492.ts (ID:492)...
# Lendo arquivo: Teste_Nanopilar_493.ts (ID:493)...
# Lendo arquivo: Teste_Nanopilar_494.ts (ID:494)...
# Lendo arquivo: Teste_Nanopilar_495.ts (ID:495)...
# Lendo arquivo: Teste_Nanopilar_496.ts (ID:496)...
# Lendo arquivo: Teste_Nanopilar_497.ts (ID:497)...
# Lendo arquivo: Teste_Nanopilar_498.ts (ID:498)...
# Lendo arquivo: Teste_Nanopilar_499.ts (ID:499)...
# Lendo arquivo: Teste_Nanopilar_5.ts (ID:5)...
# Lendo arquivo: Teste_Nanopilar_50.ts (ID:50)...
# Lendo arquivo: Teste_Nanopilar_500.ts (ID:500)...
# Lendo arquivo: Teste_Nanopilar_501.ts (ID:501)...
# Lendo arquivo: Teste_Nanopilar_502.ts (ID:502)...
# Lendo arquivo: Teste_Nanopilar_503.ts (ID:503)...
# Lendo arquivo: Teste_Nanopilar_504.ts (ID:504)...
# Lendo arquivo: Teste_Nanopilar_505.ts (ID:505)...
# Lendo arquivo: Teste_Nanopilar_506.ts (ID:506)...
# Lendo arquivo: Teste_Nanopilar_507.ts (ID:507)...
# Lendo arquivo: Teste_Nanopilar_508.ts (ID:508)...
# Lendo arquivo: Teste_Nanopilar_509.ts (ID:509)...
# Lendo arquivo: Teste_Nanopilar_51.ts (ID:51)...
# Lendo arquivo: Teste_Nanopilar_510.ts (ID:510)...
# Lendo arquivo: Teste_Nanopilar_511.ts (ID:511)...
# Lendo arquivo: Teste_Nanopilar_512.ts (ID:512)...
# Lendo arquivo: Teste_Nanopilar_513.ts (ID:513)...
# Lendo arquivo: Teste_Nanopilar_514.ts (ID:514)...
# Lendo arquivo: Teste_Nanopilar_515.ts (ID:515)...
# Lendo arquivo: Teste_Nanopilar_516.ts (ID:516)...
# Lendo arquivo: Teste_Nanopilar_517.ts (ID:517)...
# Lendo arquivo: Teste_Nanopilar_518.ts (ID:518)...
# Lendo arquivo: Teste_Nanopilar_519.ts (ID:519)...
# Lendo arquivo: Teste_Nanopilar_52.ts (ID:52)...
# Lendo arquivo: Teste_Nanopilar_520.ts (ID:520)...
# Lendo arquivo: Teste_Nanopilar_521.ts (ID:521)...
# Lendo arquivo: Teste_Nanopilar_522.ts (ID:522)...
# Lendo arquivo: Teste_Nanopilar_523.ts (ID:523)...
# Lendo arquivo: Teste_Nanopilar_524.ts (ID:524)...
# Lendo arquivo: Teste_Nanopilar_525.ts (ID:525)...
# Lendo arquivo: Teste_Nanopilar_526.ts (ID:526)...
# Lendo arquivo: Teste_Nanopilar_527.ts (ID:527)...
# Lendo arquivo: Teste_Nanopilar_528.ts (ID:528)...
# Lendo arquivo: Teste_Nanopilar_529.ts (ID:529)...
# Lendo arquivo: Teste_Nanopilar_53.ts (ID:53)...
# Lendo arquivo: Teste_Nanopilar_530.ts (ID:530)...
# Lendo arquivo: Teste_Nanopilar_531.ts (ID:531)...
# Lendo arquivo: Teste_Nanopilar_532.ts (ID:532)...
# Lendo arquivo: Teste_Nanopilar_533.ts (ID:533)...
# Lendo arquivo: Teste_Nanopilar_534.ts (ID:534)...
# Lendo arquivo: Teste_Nanopilar_535.ts (ID:535)...
# Lendo arquivo: Teste_Nanopilar_536.ts (ID:536)...
# Lendo arquivo: Teste_Nanopilar_537.ts (ID:537)...
# Lendo arquivo: Teste_Nanopilar_538.ts (ID:538)...
# Lendo arquivo: Teste_Nanopilar_539.ts (ID:539)...
# Lendo arquivo: Teste_Nanopilar_54.ts (ID:54)...
# Lendo arquivo: Teste_Nanopilar_540.ts (ID:540)...
# Lendo arquivo: Teste_Nanopilar_541.ts (ID:541)...
# Lendo arquivo: Teste_Nanopilar_542.ts (ID:542)...
# Lendo arquivo: Teste_Nanopilar_543.ts (ID:543)...
# Lendo arquivo: Teste_Nanopilar_544.ts (ID:544)...
# Lendo arquivo: Teste_Nanopilar_545.ts (ID:545)...
# Lendo arquivo: Teste_Nanopilar_546.ts (ID:546)...
# Lendo arquivo: Teste_Nanopilar_547.ts (ID:547)...
# Lendo arquivo: Teste_Nanopilar_548.ts (ID:548)...
# Lendo arquivo: Teste_Nanopilar_549.ts (ID:549)...
# Lendo arquivo: Teste_Nanopilar_55.ts (ID:55)...
# Lendo arquivo: Teste_Nanopilar_550.ts (ID:550)...
# Lendo arquivo: Teste_Nanopilar_551.ts (ID:551)...
# Lendo arquivo: Teste_Nanopilar_552.ts (ID:552)...
# Lendo arquivo: Teste_Nanopilar_553.ts (ID:553)...
# Lendo arquivo: Teste_Nanopilar_554.ts (ID:554)...
# Lendo arquivo: Teste_Nanopilar_555.ts (ID:555)...
# Lendo arquivo: Teste_Nanopilar_556.ts (ID:556)...
# Lendo arquivo: Teste_Nanopilar_557.ts (ID:557)...
# Lendo arquivo: Teste_Nanopilar_558.ts (ID:558)...
# Lendo arquivo: Teste_Nanopilar_559.ts (ID:559)...
# Lendo arquivo: Teste_Nanopilar_56.ts (ID:56)...
# Lendo arquivo: Teste_Nanopilar_560.ts (ID:560)...
# Lendo arquivo: Teste_Nanopilar_561.ts (ID:561)...
# Lendo arquivo: Teste_Nanopilar_562.ts (ID:562)...
# Lendo arquivo: Teste_Nanopilar_563.ts (ID:563)...
# Lendo arquivo: Teste_Nanopilar_564.ts (ID:564)...
# Lendo arquivo: Teste_Nanopilar_565.ts (ID:565)...
# Lendo arquivo: Teste_Nanopilar_566.ts (ID:566)...
# Lendo arquivo: Teste_Nanopilar_567.ts (ID:567)...
# Lendo arquivo: Teste_Nanopilar_568.ts (ID:568)...
# Lendo arquivo: Teste_Nanopilar_569.ts (ID:569)...
# Lendo arquivo: Teste_Nanopilar_57.ts (ID:57)...
# Lendo arquivo: Teste_Nanopilar_570.ts (ID:570)...
# Lendo arquivo: Teste_Nanopilar_571.ts (ID:571)...
# Lendo arquivo: Teste_Nanopilar_572.ts (ID:572)...
# Lendo arquivo: Teste_Nanopilar_573.ts (ID:573)...
# Lendo arquivo: Teste_Nanopilar_574.ts (ID:574)...
# Lendo arquivo: Teste_Nanopilar_575.ts (ID:575)...
# Lendo arquivo: Teste_Nanopilar_576.ts (ID:576)...
# Lendo arquivo: Teste_Nanopilar_577.ts (ID:577)...
# Lendo arquivo: Teste_Nanopilar_578.ts (ID:578)...
# Lendo arquivo: Teste_Nanopilar_579.ts (ID:579)...
# Lendo arquivo: Teste_Nanopilar_58.ts (ID:58)...
# Lendo arquivo: Teste_Nanopilar_580.ts (ID:580)...
# Lendo arquivo: Teste_Nanopilar_581.ts (ID:581)...
# Lendo arquivo: Teste_Nanopilar_582.ts (ID:582)...
# Lendo arquivo: Teste_Nanopilar_583.ts (ID:583)...
# Lendo arquivo: Teste_Nanopilar_584.ts (ID:584)...
# Lendo arquivo: Teste_Nanopilar_585.ts (ID:585)...
# Lendo arquivo: Teste_Nanopilar_586.ts (ID:586)...
# Lendo arquivo: Teste_Nanopilar_587.ts (ID:587)...
# Lendo arquivo: Teste_Nanopilar_588.ts (ID:588)...
# Lendo arquivo: Teste_Nanopilar_589.ts (ID:589)...
# Lendo arquivo: Teste_Nanopilar_59.ts (ID:59)...
# Lendo arquivo: Teste_Nanopilar_590.ts (ID:590)...
# Lendo arquivo: Teste_Nanopilar_591.ts (ID:591)...
# Lendo arquivo: Teste_Nanopilar_592.ts (ID:592)...
# Lendo arquivo: Teste_Nanopilar_593.ts (ID:593)...
# Lendo arquivo: Teste_Nanopilar_594.ts (ID:594)...
# Lendo arquivo: Teste_Nanopilar_595.ts (ID:595)...
# Lendo arquivo: Teste_Nanopilar_596.ts (ID:596)...
# Lendo arquivo: Teste_Nanopilar_597.ts (ID:597)...
# Lendo arquivo: Teste_Nanopilar_598.ts (ID:598)...
# Lendo arquivo: Teste_Nanopilar_599.ts (ID:599)...
# Lendo arquivo: Teste_Nanopilar_6.ts (ID:6)...
# Lendo arquivo: Teste_Nanopilar_60.ts (ID:60)...
# Lendo arquivo: Teste_Nanopilar_600.ts (ID:600)...
# Lendo arquivo: Teste_Nanopilar_601.ts (ID:601)...
# Lendo arquivo: Teste_Nanopilar_602.ts (ID:602)...
# Lendo arquivo: Teste_Nanopilar_603.ts (ID:603)...
# Lendo arquivo: Teste_Nanopilar_604.ts (ID:604)...
# Lendo arquivo: Teste_Nanopilar_605.ts (ID:605)...
# Lendo arquivo: Teste_Nanopilar_606.ts (ID:606)...
# Lendo arquivo: Teste_Nanopilar_607.ts (ID:607)...
# Lendo arquivo: Teste_Nanopilar_608.ts (ID:608)...
# Lendo arquivo: Teste_Nanopilar_609.ts (ID:609)...
# Lendo arquivo: Teste_Nanopilar_61.ts (ID:61)...
# Lendo arquivo: Teste_Nanopilar_610.ts (ID:610)...
# Lendo arquivo: Teste_Nanopilar_611.ts (ID:611)...
# Lendo arquivo: Teste_Nanopilar_612.ts (ID:612)...
# Lendo arquivo: Teste_Nanopilar_613.ts (ID:613)...
# Lendo arquivo: Teste_Nanopilar_614.ts (ID:614)...
# Lendo arquivo: Teste_Nanopilar_615.ts (ID:615)...
# Lendo arquivo: Teste_Nanopilar_616.ts (ID:616)...
# Lendo arquivo: Teste_Nanopilar_617.ts (ID:617)...
# Lendo arquivo: Teste_Nanopilar_618.ts (ID:618)...
# Lendo arquivo: Teste_Nanopilar_619.ts (ID:619)...
# Lendo arquivo: Teste_Nanopilar_62.ts (ID:62)...
# Lendo arquivo: Teste_Nanopilar_620.ts (ID:620)...
# Lendo arquivo: Teste_Nanopilar_621.ts (ID:621)...
# Lendo arquivo: Teste_Nanopilar_622.ts (ID:622)...
# Lendo arquivo: Teste_Nanopilar_623.ts (ID:623)...
# Lendo arquivo: Teste_Nanopilar_624.ts (ID:624)...
# Lendo arquivo: Teste_Nanopilar_625.ts (ID:625)...
# Lendo arquivo: Teste_Nanopilar_626.ts (ID:626)...
# Lendo arquivo: Teste_Nanopilar_627.ts (ID:627)...
# Lendo arquivo: Teste_Nanopilar_628.ts (ID:628)...
# Lendo arquivo: Teste_Nanopilar_629.ts (ID:629)...
# Lendo arquivo: Teste_Nanopilar_63.ts (ID:63)...
# Lendo arquivo: Teste_Nanopilar_630.ts (ID:630)...
# Lendo arquivo: Teste_Nanopilar_631.ts (ID:631)...
# Lendo arquivo: Teste_Nanopilar_632.ts (ID:632)...
# Lendo arquivo: Teste_Nanopilar_633.ts (ID:633)...
# Lendo arquivo: Teste_Nanopilar_634.ts (ID:634)...
# Lendo arquivo: Teste_Nanopilar_635.ts (ID:635)...
# Lendo arquivo: Teste_Nanopilar_636.ts (ID:636)...
# Lendo arquivo: Teste_Nanopilar_637.ts (ID:637)...
# Lendo arquivo: Teste_Nanopilar_638.ts (ID:638)...
# Lendo arquivo: Teste_Nanopilar_639.ts (ID:639)...
# Lendo arquivo: Teste_Nanopilar_64.ts (ID:64)...
# Lendo arquivo: Teste_Nanopilar_640.ts (ID:640)...
# Lendo arquivo: Teste_Nanopilar_641.ts (ID:641)...
# Lendo arquivo: Teste_Nanopilar_642.ts (ID:642)...
# Lendo arquivo: Teste_Nanopilar_643.ts (ID:643)...
# Lendo arquivo: Teste_Nanopilar_644.ts (ID:644)...
# Lendo arquivo: Teste_Nanopilar_645.ts (ID:645)...
# Lendo arquivo: Teste_Nanopilar_646.ts (ID:646)...
# Lendo arquivo: Teste_Nanopilar_647.ts (ID:647)...
# Lendo arquivo: Teste_Nanopilar_648.ts (ID:648)...
# Lendo arquivo: Teste_Nanopilar_649.ts (ID:649)...
# Lendo arquivo: Teste_Nanopilar_65.ts (ID:65)...
# Lendo arquivo: Teste_Nanopilar_650.ts (ID:650)...
# Lendo arquivo: Teste_Nanopilar_651.ts (ID:651)...
# Lendo arquivo: Teste_Nanopilar_652.ts (ID:652)...
# Lendo arquivo: Teste_Nanopilar_653.ts (ID:653)...
# Lendo arquivo: Teste_Nanopilar_654.ts (ID:654)...
# Lendo arquivo: Teste_Nanopilar_655.ts (ID:655)...
# Lendo arquivo: Teste_Nanopilar_656.ts (ID:656)...
# Lendo arquivo: Teste_Nanopilar_657.ts (ID:657)...
# Lendo arquivo: Teste_Nanopilar_658.ts (ID:658)...
# Lendo arquivo: Teste_Nanopilar_659.ts (ID:659)...
# Lendo arquivo: Teste_Nanopilar_66.ts (ID:66)...
# Lendo arquivo: Teste_Nanopilar_660.ts (ID:660)...
# Lendo arquivo: Teste_Nanopilar_661.ts (ID:661)...
# Lendo arquivo: Teste_Nanopilar_662.ts (ID:662)...
# Lendo arquivo: Teste_Nanopilar_663.ts (ID:663)...
# Lendo arquivo: Teste_Nanopilar_664.ts (ID:664)...
# Lendo arquivo: Teste_Nanopilar_665.ts (ID:665)...
# Lendo arquivo: Teste_Nanopilar_666.ts (ID:666)...
# Lendo arquivo: Teste_Nanopilar_667.ts (ID:667)...
# Lendo arquivo: Teste_Nanopilar_668.ts (ID:668)...
# Lendo arquivo: Teste_Nanopilar_669.ts (ID:669)...
# Lendo arquivo: Teste_Nanopilar_67.ts (ID:67)...
# Lendo arquivo: Teste_Nanopilar_670.ts (ID:670)...
# Lendo arquivo: Teste_Nanopilar_671.ts (ID:671)...
# Lendo arquivo: Teste_Nanopilar_672.ts (ID:672)...
# Lendo arquivo: Teste_Nanopilar_673.ts (ID:673)...
# Lendo arquivo: Teste_Nanopilar_674.ts (ID:674)...
# Lendo arquivo: Teste_Nanopilar_675.ts (ID:675)...
# Lendo arquivo: Teste_Nanopilar_676.ts (ID:676)...
# Lendo arquivo: Teste_Nanopilar_677.ts (ID:677)...
# Lendo arquivo: Teste_Nanopilar_678.ts (ID:678)...
# Lendo arquivo: Teste_Nanopilar_679.ts (ID:679)...
# Lendo arquivo: Teste_Nanopilar_68.ts (ID:68)...
# Lendo arquivo: Teste_Nanopilar_680.ts (ID:680)...
# Lendo arquivo: Teste_Nanopilar_681.ts (ID:681)...
# Lendo arquivo: Teste_Nanopilar_682.ts (ID:682)...
# Lendo arquivo: Teste_Nanopilar_683.ts (ID:683)...
# Lendo arquivo: Teste_Nanopilar_684.ts (ID:684)...
# Lendo arquivo: Teste_Nanopilar_685.ts (ID:685)...
# Lendo arquivo: Teste_Nanopilar_686.ts (ID:686)...
# Lendo arquivo: Teste_Nanopilar_687.ts (ID:687)...
# Lendo arquivo: Teste_Nanopilar_688.ts (ID:688)...
# Lendo arquivo: Teste_Nanopilar_689.ts (ID:689)...
# Lendo arquivo: Teste_Nanopilar_69.ts (ID:69)...
# Lendo arquivo: Teste_Nanopilar_690.ts (ID:690)...
# Lendo arquivo: Teste_Nanopilar_691.ts (ID:691)...
# Lendo arquivo: Teste_Nanopilar_692.ts (ID:692)...
# Lendo arquivo: Teste_Nanopilar_693.ts (ID:693)...
# Lendo arquivo: Teste_Nanopilar_694.ts (ID:694)...
# Lendo arquivo: Teste_Nanopilar_695.ts (ID:695)...
# Lendo arquivo: Teste_Nanopilar_696.ts (ID:696)...
# Lendo arquivo: Teste_Nanopilar_697.ts (ID:697)...
# Lendo arquivo: Teste_Nanopilar_698.ts (ID:698)...
# Lendo arquivo: Teste_Nanopilar_699.ts (ID:699)...
# Lendo arquivo: Teste_Nanopilar_7.ts (ID:7)...
# Lendo arquivo: Teste_Nanopilar_70.ts (ID:70)...
# Lendo arquivo: Teste_Nanopilar_700.ts (ID:700)...
# Lendo arquivo: Teste_Nanopilar_701.ts (ID:701)...
# Lendo arquivo: Teste_Nanopilar_702.ts (ID:702)...
# Lendo arquivo: Teste_Nanopilar_703.ts (ID:703)...
# Lendo arquivo: Teste_Nanopilar_704.ts (ID:704)...
# Lendo arquivo: Teste_Nanopilar_705.ts (ID:705)...
# Lendo arquivo: Teste_Nanopilar_706.ts (ID:706)...
# Lendo arquivo: Teste_Nanopilar_707.ts (ID:707)...
# Lendo arquivo: Teste_Nanopilar_708.ts (ID:708)...
# Lendo arquivo: Teste_Nanopilar_709.ts (ID:709)...
# Lendo arquivo: Teste_Nanopilar_71.ts (ID:71)...
# Lendo arquivo: Teste_Nanopilar_710.ts (ID:710)...
# Lendo arquivo: Teste_Nanopilar_711.ts (ID:711)...
# Lendo arquivo: Teste_Nanopilar_712.ts (ID:712)...
# Lendo arquivo: Teste_Nanopilar_713.ts (ID:713)...
# Lendo arquivo: Teste_Nanopilar_714.ts (ID:714)...
# Lendo arquivo: Teste_Nanopilar_715.ts (ID:715)...
# Lendo arquivo: Teste_Nanopilar_716.ts (ID:716)...
# Lendo arquivo: Teste_Nanopilar_717.ts (ID:717)...
# Lendo arquivo: Teste_Nanopilar_718.ts (ID:718)...
# Lendo arquivo: Teste_Nanopilar_719.ts (ID:719)...
# Lendo arquivo: Teste_Nanopilar_72.ts (ID:72)...
# Lendo arquivo: Teste_Nanopilar_720.ts (ID:720)...
# Lendo arquivo: Teste_Nanopilar_721.ts (ID:721)...
# Lendo arquivo: Teste_Nanopilar_722.ts (ID:722)...
# Lendo arquivo: Teste_Nanopilar_723.ts (ID:723)...
# Lendo arquivo: Teste_Nanopilar_724.ts (ID:724)...
# Lendo arquivo: Teste_Nanopilar_725.ts (ID:725)...
# Lendo arquivo: Teste_Nanopilar_726.ts (ID:726)...
# Lendo arquivo: Teste_Nanopilar_727.ts (ID:727)...
# Lendo arquivo: Teste_Nanopilar_728.ts (ID:728)...
# Lendo arquivo: Teste_Nanopilar_729.ts (ID:729)...
# Lendo arquivo: Teste_Nanopilar_73.ts (ID:73)...
# Lendo arquivo: Teste_Nanopilar_730.ts (ID:730)...
# Lendo arquivo: Teste_Nanopilar_731.ts (ID:731)...
# Lendo arquivo: Teste_Nanopilar_732.ts (ID:732)...
# Lendo arquivo: Teste_Nanopilar_733.ts (ID:733)...
# Lendo arquivo: Teste_Nanopilar_734.ts (ID:734)...
# Lendo arquivo: Teste_Nanopilar_735.ts (ID:735)...
# Lendo arquivo: Teste_Nanopilar_736.ts (ID:736)...
# Lendo arquivo: Teste_Nanopilar_737.ts (ID:737)...
# Lendo arquivo: Teste_Nanopilar_738.ts (ID:738)...
# Lendo arquivo: Teste_Nanopilar_739.ts (ID:739)...
# Lendo arquivo: Teste_Nanopilar_74.ts (ID:74)...
# Lendo arquivo: Teste_Nanopilar_740.ts (ID:740)...
# Lendo arquivo: Teste_Nanopilar_741.ts (ID:741)...
# Lendo arquivo: Teste_Nanopilar_742.ts (ID:742)...
# Lendo arquivo: Teste_Nanopilar_743.ts (ID:743)...
# Lendo arquivo: Teste_Nanopilar_744.ts (ID:744)...
# Lendo arquivo: Teste_Nanopilar_745.ts (ID:745)...
# Lendo arquivo: Teste_Nanopilar_746.ts (ID:746)...
# Lendo arquivo: Teste_Nanopilar_747.ts (ID:747)...
# Lendo arquivo: Teste_Nanopilar_748.ts (ID:748)...
# Lendo arquivo: Teste_Nanopilar_749.ts (ID:749)...
# Lendo arquivo: Teste_Nanopilar_75.ts (ID:75)...
# Lendo arquivo: Teste_Nanopilar_750.ts (ID:750)...
# Lendo arquivo: Teste_Nanopilar_751.ts (ID:751)...
# Lendo arquivo: Teste_Nanopilar_752.ts (ID:752)...
# Lendo arquivo: Teste_Nanopilar_753.ts (ID:753)...
# Lendo arquivo: Teste_Nanopilar_754.ts (ID:754)...
# Lendo arquivo: Teste_Nanopilar_755.ts (ID:755)...
# Lendo arquivo: Teste_Nanopilar_756.ts (ID:756)...
# Lendo arquivo: Teste_Nanopilar_757.ts (ID:757)...
# Lendo arquivo: Teste_Nanopilar_758.ts (ID:758)...
# Lendo arquivo: Teste_Nanopilar_759.ts (ID:759)...
# Lendo arquivo: Teste_Nanopilar_76.ts (ID:76)...
# Lendo arquivo: Teste_Nanopilar_760.ts (ID:760)...
# Lendo arquivo: Teste_Nanopilar_761.ts (ID:761)...
# Lendo arquivo: Teste_Nanopilar_762.ts (ID:762)...
# Lendo arquivo: Teste_Nanopilar_763.ts (ID:763)...
# Lendo arquivo: Teste_Nanopilar_764.ts (ID:764)...
# Lendo arquivo: Teste_Nanopilar_765.ts (ID:765)...
# Lendo arquivo: Teste_Nanopilar_766.ts (ID:766)...
# Lendo arquivo: Teste_Nanopilar_767.ts (ID:767)...
# Lendo arquivo: Teste_Nanopilar_768.ts (ID:768)...
# Lendo arquivo: Teste_Nanopilar_769.ts (ID:769)...
# Lendo arquivo: Teste_Nanopilar_77.ts (ID:77)...
# Lendo arquivo: Teste_Nanopilar_770.ts (ID:770)...
# Lendo arquivo: Teste_Nanopilar_771.ts (ID:771)...
# Lendo arquivo: Teste_Nanopilar_772.ts (ID:772)...
# Lendo arquivo: Teste_Nanopilar_773.ts (ID:773)...
# Lendo arquivo: Teste_Nanopilar_774.ts (ID:774)...
# Lendo arquivo: Teste_Nanopilar_775.ts (ID:775)...
# Lendo arquivo: Teste_Nanopilar_776.ts (ID:776)...
# Lendo arquivo: Teste_Nanopilar_777.ts (ID:777)...
# Lendo arquivo: Teste_Nanopilar_778.ts (ID:778)...
# Lendo arquivo: Teste_Nanopilar_779.ts (ID:779)...
# Lendo arquivo: Teste_Nanopilar_78.ts (ID:78)...
# Lendo arquivo: Teste_Nanopilar_780.ts (ID:780)...
# Lendo arquivo: Teste_Nanopilar_781.ts (ID:781)...
# Lendo arquivo: Teste_Nanopilar_782.ts (ID:782)...
# Lendo arquivo: Teste_Nanopilar_783.ts (ID:783)...
# Lendo arquivo: Teste_Nanopilar_784.ts (ID:784)...
# Lendo arquivo: Teste_Nanopilar_785.ts (ID:785)...
# Lendo arquivo: Teste_Nanopilar_786.ts (ID:786)...
# Lendo arquivo: Teste_Nanopilar_787.ts (ID:787)...
# Lendo arquivo: Teste_Nanopilar_788.ts (ID:788)...
# Lendo arquivo: Teste_Nanopilar_789.ts (ID:789)...
# Lendo arquivo: Teste_Nanopilar_79.ts (ID:79)...
# Lendo arquivo: Teste_Nanopilar_790.ts (ID:790)...
# Lendo arquivo: Teste_Nanopilar_791.ts (ID:791)...
# Lendo arquivo: Teste_Nanopilar_792.ts (ID:792)...
# Lendo arquivo: Teste_Nanopilar_793.ts (ID:793)...
# Lendo arquivo: Teste_Nanopilar_794.ts (ID:794)...
# Lendo arquivo: Teste_Nanopilar_795.ts (ID:795)...
# Lendo arquivo: Teste_Nanopilar_796.ts (ID:796)...
# Lendo arquivo: Teste_Nanopilar_797.ts (ID:797)...
# Lendo arquivo: Teste_Nanopilar_798.ts (ID:798)...
# Lendo arquivo: Teste_Nanopilar_799.ts (ID:799)...
# Lendo arquivo: Teste_Nanopilar_8.ts (ID:8)...
# Lendo arquivo: Teste_Nanopilar_80.ts (ID:80)...
# Lendo arquivo: Teste_Nanopilar_800.ts (ID:800)...
# Lendo arquivo: Teste_Nanopilar_801.ts (ID:801)...
# Lendo arquivo: Teste_Nanopilar_802.ts (ID:802)...
# Lendo arquivo: Teste_Nanopilar_803.ts (ID:803)...
# Lendo arquivo: Teste_Nanopilar_804.ts (ID:804)...
# Lendo arquivo: Teste_Nanopilar_805.ts (ID:805)...
# Lendo arquivo: Teste_Nanopilar_806.ts (ID:806)...
# Lendo arquivo: Teste_Nanopilar_807.ts (ID:807)...
# Lendo arquivo: Teste_Nanopilar_808.ts (ID:808)...
# Lendo arquivo: Teste_Nanopilar_809.ts (ID:809)...
# Lendo arquivo: Teste_Nanopilar_81.ts (ID:81)...
# Lendo arquivo: Teste_Nanopilar_810.ts (ID:810)...
# Lendo arquivo: Teste_Nanopilar_811.ts (ID:811)...
# Lendo arquivo: Teste_Nanopilar_812.ts (ID:812)...
# Lendo arquivo: Teste_Nanopilar_813.ts (ID:813)...
# Lendo arquivo: Teste_Nanopilar_814.ts (ID:814)...
# Lendo arquivo: Teste_Nanopilar_815.ts (ID:815)...
# Lendo arquivo: Teste_Nanopilar_816.ts (ID:816)...
# Lendo arquivo: Teste_Nanopilar_817.ts (ID:817)...
# Lendo arquivo: Teste_Nanopilar_818.ts (ID:818)...
# Lendo arquivo: Teste_Nanopilar_819.ts (ID:819)...
# Lendo arquivo: Teste_Nanopilar_82.ts (ID:82)...
# Lendo arquivo: Teste_Nanopilar_820.ts (ID:820)...
# Lendo arquivo: Teste_Nanopilar_821.ts (ID:821)...
# Lendo arquivo: Teste_Nanopilar_822.ts (ID:822)...
# Lendo arquivo: Teste_Nanopilar_823.ts (ID:823)...
# Lendo arquivo: Teste_Nanopilar_824.ts (ID:824)...
# Lendo arquivo: Teste_Nanopilar_825.ts (ID:825)...
# Lendo arquivo: Teste_Nanopilar_826.ts (ID:826)...
# Lendo arquivo: Teste_Nanopilar_827.ts (ID:827)...
# Lendo arquivo: Teste_Nanopilar_828.ts (ID:828)...
# Lendo arquivo: Teste_Nanopilar_829.ts (ID:829)...
# Lendo arquivo: Teste_Nanopilar_83.ts (ID:83)...
# Lendo arquivo: Teste_Nanopilar_830.ts (ID:830)...
# Lendo arquivo: Teste_Nanopilar_831.ts (ID:831)...
# Lendo arquivo: Teste_Nanopilar_832.ts (ID:832)...
# Lendo arquivo: Teste_Nanopilar_833.ts (ID:833)...
# Lendo arquivo: Teste_Nanopilar_834.ts (ID:834)...
# Lendo arquivo: Teste_Nanopilar_835.ts (ID:835)...
# Lendo arquivo: Teste_Nanopilar_836.ts (ID:836)...
# Lendo arquivo: Teste_Nanopilar_837.ts (ID:837)...
# Lendo arquivo: Teste_Nanopilar_838.ts (ID:838)...
# Lendo arquivo: Teste_Nanopilar_839.ts (ID:839)...
# Lendo arquivo: Teste_Nanopilar_84.ts (ID:84)...
# Lendo arquivo: Teste_Nanopilar_840.ts (ID:840)...
# Lendo arquivo: Teste_Nanopilar_841.ts (ID:841)...
# Lendo arquivo: Teste_Nanopilar_842.ts (ID:842)...
# Lendo arquivo: Teste_Nanopilar_843.ts (ID:843)...
# Lendo arquivo: Teste_Nanopilar_844.ts (ID:844)...
# Lendo arquivo: Teste_Nanopilar_845.ts (ID:845)...
# Lendo arquivo: Teste_Nanopilar_846.ts (ID:846)...
# Lendo arquivo: Teste_Nanopilar_847.ts (ID:847)...
# Lendo arquivo: Teste_Nanopilar_848.ts (ID:848)...
# Lendo arquivo: Teste_Nanopilar_849.ts (ID:849)...
# Lendo arquivo: Teste_Nanopilar_85.ts (ID:85)...
# Lendo arquivo: Teste_Nanopilar_850.ts (ID:850)...
# Lendo arquivo: Teste_Nanopilar_851.ts (ID:851)...
# Lendo arquivo: Teste_Nanopilar_852.ts (ID:852)...
# Lendo arquivo: Teste_Nanopilar_853.ts (ID:853)...
# Lendo arquivo: Teste_Nanopilar_854.ts (ID:854)...
# Lendo arquivo: Teste_Nanopilar_855.ts (ID:855)...
# Lendo arquivo: Teste_Nanopilar_856.ts (ID:856)...
# Lendo arquivo: Teste_Nanopilar_857.ts (ID:857)...
# Lendo arquivo: Teste_Nanopilar_858.ts (ID:858)...
# Lendo arquivo: Teste_Nanopilar_859.ts (ID:859)...
# Lendo arquivo: Teste_Nanopilar_86.ts (ID:86)...
# Lendo arquivo: Teste_Nanopilar_860.ts (ID:860)...
# Lendo arquivo: Teste_Nanopilar_861.ts (ID:861)...
# Lendo arquivo: Teste_Nanopilar_862.ts (ID:862)...
# Lendo arquivo: Teste_Nanopilar_863.ts (ID:863)...
# Lendo arquivo: Teste_Nanopilar_864.ts (ID:864)...
# Lendo arquivo: Teste_Nanopilar_865.ts (ID:865)...
# Lendo arquivo: Teste_Nanopilar_866.ts (ID:866)...
# Lendo arquivo: Teste_Nanopilar_867.ts (ID:867)...
# Lendo arquivo: Teste_Nanopilar_868.ts (ID:868)...
# Lendo arquivo: Teste_Nanopilar_869.ts (ID:869)...
# Lendo arquivo: Teste_Nanopilar_87.ts (ID:87)...
# Lendo arquivo: Teste_Nanopilar_870.ts (ID:870)...
# Lendo arquivo: Teste_Nanopilar_871.ts (ID:871)...
# Lendo arquivo: Teste_Nanopilar_872.ts (ID:872)...
# Lendo arquivo: Teste_Nanopilar_873.ts (ID:873)...
# Lendo arquivo: Teste_Nanopilar_874.ts (ID:874)...
# Lendo arquivo: Teste_Nanopilar_875.ts (ID:875)...
# Lendo arquivo: Teste_Nanopilar_876.ts (ID:876)...
# Lendo arquivo: Teste_Nanopilar_877.ts (ID:877)...
# Lendo arquivo: Teste_Nanopilar_878.ts (ID:878)...
# Lendo arquivo: Teste_Nanopilar_879.ts (ID:879)...
# Lendo arquivo: Teste_Nanopilar_88.ts (ID:88)...
# Lendo arquivo: Teste_Nanopilar_880.ts (ID:880)...
# Lendo arquivo: Teste_Nanopilar_881.ts (ID:881)...
# Lendo arquivo: Teste_Nanopilar_882.ts (ID:882)...
# Lendo arquivo: Teste_Nanopilar_883.ts (ID:883)...
# Lendo arquivo: Teste_Nanopilar_884.ts (ID:884)...
# Lendo arquivo: Teste_Nanopilar_885.ts (ID:885)...
# Lendo arquivo: Teste_Nanopilar_886.ts (ID:886)...
# Lendo arquivo: Teste_Nanopilar_887.ts (ID:887)...
# Lendo arquivo: Teste_Nanopilar_888.ts (ID:888)...
# Lendo arquivo: Teste_Nanopilar_889.ts (ID:889)...
# Lendo arquivo: Teste_Nanopilar_89.ts (ID:89)...
# Lendo arquivo: Teste_Nanopilar_890.ts (ID:890)...
# Lendo arquivo: Teste_Nanopilar_891.ts (ID:891)...
# Lendo arquivo: Teste_Nanopilar_892.ts (ID:892)...
# Lendo arquivo: Teste_Nanopilar_893.ts (ID:893)...
# Lendo arquivo: Teste_Nanopilar_894.ts (ID:894)...
# Lendo arquivo: Teste_Nanopilar_895.ts (ID:895)...
# Lendo arquivo: Teste_Nanopilar_896.ts (ID:896)...
# Lendo arquivo: Teste_Nanopilar_897.ts (ID:897)...
# Lendo arquivo: Teste_Nanopilar_898.ts (ID:898)...
# Lendo arquivo: Teste_Nanopilar_899.ts (ID:899)...
# Lendo arquivo: Teste_Nanopilar_9.ts (ID:9)...
# Lendo arquivo: Teste_Nanopilar_90.ts (ID:90)...
# Lendo arquivo: Teste_Nanopilar_900.ts (ID:900)...
# Lendo arquivo: Teste_Nanopilar_901.ts (ID:901)...
# Lendo arquivo: Teste_Nanopilar_902.ts (ID:902)...
# Lendo arquivo: Teste_Nanopilar_903.ts (ID:903)...
# Lendo arquivo: Teste_Nanopilar_904.ts (ID:904)...
# Lendo arquivo: Teste_Nanopilar_905.ts (ID:905)...
# Lendo arquivo: Teste_Nanopilar_906.ts (ID:906)...
# Lendo arquivo: Teste_Nanopilar_907.ts (ID:907)...
# Lendo arquivo: Teste_Nanopilar_908.ts (ID:908)...
# Lendo arquivo: Teste_Nanopilar_909.ts (ID:909)...
# Lendo arquivo: Teste_Nanopilar_91.ts (ID:91)...
# Lendo arquivo: Teste_Nanopilar_910.ts (ID:910)...
# Lendo arquivo: Teste_Nanopilar_911.ts (ID:911)...
# Lendo arquivo: Teste_Nanopilar_912.ts (ID:912)...
# Lendo arquivo: Teste_Nanopilar_913.ts (ID:913)...
# Lendo arquivo: Teste_Nanopilar_914.ts (ID:914)...
# Lendo arquivo: Teste_Nanopilar_915.ts (ID:915)...
# Lendo arquivo: Teste_Nanopilar_916.ts (ID:916)...
# Lendo arquivo: Teste_Nanopilar_917.ts (ID:917)...
# Lendo arquivo: Teste_Nanopilar_918.ts (ID:918)...
# Lendo arquivo: Teste_Nanopilar_919.ts (ID:919)...
# Lendo arquivo: Teste_Nanopilar_92.ts (ID:92)...
# Lendo arquivo: Teste_Nanopilar_920.ts (ID:920)...
# Lendo arquivo: Teste_Nanopilar_921.ts (ID:921)...
# Lendo arquivo: Teste_Nanopilar_922.ts (ID:922)...
# Lendo arquivo: Teste_Nanopilar_923.ts (ID:923)...
# Lendo arquivo: Teste_Nanopilar_924.ts (ID:924)...
# Lendo arquivo: Teste_Nanopilar_925.ts (ID:925)...
# Lendo arquivo: Teste_Nanopilar_926.ts (ID:926)...
# Lendo arquivo: Teste_Nanopilar_927.ts (ID:927)...
# Lendo arquivo: Teste_Nanopilar_928.ts (ID:928)...
# Lendo arquivo: Teste_Nanopilar_929.ts (ID:929)...
# Lendo arquivo: Teste_Nanopilar_93.ts (ID:93)...
# Lendo arquivo: Teste_Nanopilar_930.ts (ID:930)...
# Lendo arquivo: Teste_Nanopilar_931.ts (ID:931)...
# Lendo arquivo: Teste_Nanopilar_932.ts (ID:932)...
# Lendo arquivo: Teste_Nanopilar_933.ts (ID:933)...
# Lendo arquivo: Teste_Nanopilar_934.ts (ID:934)...
# Lendo arquivo: Teste_Nanopilar_935.ts (ID:935)...
# Lendo arquivo: Teste_Nanopilar_936.ts (ID:936)...
# Lendo arquivo: Teste_Nanopilar_937.ts (ID:937)...
# Lendo arquivo: Teste_Nanopilar_938.ts (ID:938)...
# Lendo arquivo: Teste_Nanopilar_939.ts (ID:939)...
# Lendo arquivo: Teste_Nanopilar_94.ts (ID:94)...
# Lendo arquivo: Teste_Nanopilar_940.ts (ID:940)...
# Lendo arquivo: Teste_Nanopilar_941.ts (ID:941)...
# Lendo arquivo: Teste_Nanopilar_942.ts (ID:942)...
# Lendo arquivo: Teste_Nanopilar_943.ts (ID:943)...
# Lendo arquivo: Teste_Nanopilar_944.ts (ID:944)...
# Lendo arquivo: Teste_Nanopilar_945.ts (ID:945)...
# Lendo arquivo: Teste_Nanopilar_946.ts (ID:946)...
# Lendo arquivo: Teste_Nanopilar_947.ts (ID:947)...
# Lendo arquivo: Teste_Nanopilar_948.ts (ID:948)...
# Lendo arquivo: Teste_Nanopilar_949.ts (ID:949)...
# Lendo arquivo: Teste_Nanopilar_95.ts (ID:95)...
# Lendo arquivo: Teste_Nanopilar_950.ts (ID:950)...
# Lendo arquivo: Teste_Nanopilar_951.ts (ID:951)...
# Lendo arquivo: Teste_Nanopilar_952.ts (ID:952)...
# Lendo arquivo: Teste_Nanopilar_953.ts (ID:953)...
# Lendo arquivo: Teste_Nanopilar_954.ts (ID:954)...
# Lendo arquivo: Teste_Nanopilar_955.ts (ID:955)...
# Lendo arquivo: Teste_Nanopilar_956.ts (ID:956)...
# Lendo arquivo: Teste_Nanopilar_957.ts (ID:957)...
# Lendo arquivo: Teste_Nanopilar_958.ts (ID:958)...
# Lendo arquivo: Teste_Nanopilar_959.ts (ID:959)...
# Lendo arquivo: Teste_Nanopilar_96.ts (ID:96)...
# Lendo arquivo: Teste_Nanopilar_960.ts (ID:960)...
# Lendo arquivo: Teste_Nanopilar_961.ts (ID:961)...
# Lendo arquivo: Teste_Nanopilar_962.ts (ID:962)...
# Lendo arquivo: Teste_Nanopilar_963.ts (ID:963)...
# Lendo arquivo: Teste_Nanopilar_964.ts (ID:964)...
# Lendo arquivo: Teste_Nanopilar_965.ts (ID:965)...
# Lendo arquivo: Teste_Nanopilar_966.ts (ID:966)...
# Lendo arquivo: Teste_Nanopilar_967.ts (ID:967)...
# Lendo arquivo: Teste_Nanopilar_968.ts (ID:968)...
# Lendo arquivo: Teste_Nanopilar_969.ts (ID:969)...
# Lendo arquivo: Teste_Nanopilar_97.ts (ID:97)...
# Lendo arquivo: Teste_Nanopilar_970.ts (ID:970)...
# Lendo arquivo: Teste_Nanopilar_971.ts (ID:971)...
# Lendo arquivo: Teste_Nanopilar_972.ts (ID:972)...
# Lendo arquivo: Teste_Nanopilar_973.ts (ID:973)...
# Lendo arquivo: Teste_Nanopilar_974.ts (ID:974)...
# Lendo arquivo: Teste_Nanopilar_975.ts (ID:975)...
# Lendo arquivo: Teste_Nanopilar_976.ts (ID:976)...
# Lendo arquivo: Teste_Nanopilar_977.ts (ID:977)...
# Lendo arquivo: Teste_Nanopilar_978.ts (ID:978)...
# Lendo arquivo: Teste_Nanopilar_979.ts (ID:979)...
# Lendo arquivo: Teste_Nanopilar_98.ts (ID:98)...
# Lendo arquivo: Teste_Nanopilar_980.ts (ID:980)...
# Lendo arquivo: Teste_Nanopilar_981.ts (ID:981)...
# Lendo arquivo: Teste_Nanopilar_982.ts (ID:982)...
# Lendo arquivo: Teste_Nanopilar_983.ts (ID:983)...
# Lendo arquivo: Teste_Nanopilar_984.ts (ID:984)...
# Lendo arquivo: Teste_Nanopilar_985.ts (ID:985)...
# Lendo arquivo: Teste_Nanopilar_986.ts (ID:986)...
# Lendo arquivo: Teste_Nanopilar_987.ts (ID:987)...
# Lendo arquivo: Teste_Nanopilar_988.ts (ID:988)...
# Lendo arquivo: Teste_Nanopilar_989.ts (ID:989)...
# Lendo arquivo: Teste_Nanopilar_99.ts (ID:99)...
# Lendo arquivo: Teste_Nanopilar_990.ts (ID:990)...
# Lendo arquivo: Teste_Nanopilar_991.ts (ID:991)...
# Lendo arquivo: Teste_Nanopilar_992.ts (ID:992)...
# Lendo arquivo: Teste_Nanopilar_993.ts (ID:993)...
# Lendo arquivo: Teste_Nanopilar_994.ts (ID:994)...
# Lendo arquivo: Teste_Nanopilar_995.ts (ID:995)...
# Lendo arquivo: Teste_Nanopilar_996.ts (ID:996)...
# Lendo arquivo: Teste_Nanopilar_997.ts (ID:997)...
# Lendo arquivo: Teste_Nanopilar_998.ts (ID:998)...
# Lendo arquivo: Teste_Nanopilar_999.ts (ID:999)...
#
# --- DataFrame carregado com sucesso! ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 51 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   arquivo         2350 non-null   object
#  1   caminho         2350 non-null   object
#  2   id_nanopilar    2350 non-null   int64
#  3   frequencia_hz   2350 non-null   float64
#  4   frequencia_ghz  2350 non-null   float64
#  5   nports          2350 non-null   int64
#  6   H               2350 non-null   float64
#  7   L_x             2350 non-null   float64
#  8   L_y             2350 non-null   float64
#  9   Lambda          2350 non-null   float64
#  10  Max_L           2350 non-null   float64
#  11  Min_L           2350 non-null   float64
#  12  PathPara        2350 non-null   float64
#  13  Phi             2350 non-null   float64
#  14  Step_L          2350 non-null   float64
#  15  Theta           2350 non-null   float64
#  16  p               2350 non-null   float64
#  17  phaseX          2350 non-null   float64
#  18  phaseY          2350 non-null   float64
#  19  S11_real        2350 non-null   float64
#  20  S11_imag        2350 non-null   float64
#  21  S12_real        2350 non-null   float64
#  22  S12_imag        2350 non-null   float64
#  23  S13_real        2350 non-null   float64
#  24  S13_imag        2350 non-null   float64
#  25  S14_real        2350 non-null   float64
#  26  S14_imag        2350 non-null   float64
#  27  S21_real        2350 non-null   float64
#  28  S21_imag        2350 non-null   float64
#  29  S22_real        2350 non-null   float64
#  30  S22_imag        2350 non-null   float64
#  31  S23_real        2350 non-null   float64
#  32  S23_imag        2350 non-null   float64
#  33  S24_real        2350 non-null   float64
#  34  S24_imag        2350 non-null   float64
#  35  S31_real        2350 non-null   float64
#  36  S31_imag        2350 non-null   float64
#  37  S32_real        2350 non-null   float64
#  38  S32_imag        2350 non-null   float64
#  39  S33_real        2350 non-null   float64
#  40  S33_imag        2350 non-null   float64
#  41  S34_real        2350 non-null   float64
#  42  S34_imag        2350 non-null   float64
#  43  S41_real        2350 non-null   float64
#  44  S41_imag        2350 non-null   float64
#  45  S42_real        2350 non-null   float64
#  46  S42_imag        2350 non-null   float64
#  47  S43_real        2350 non-null   float64
#  48  S43_imag        2350 non-null   float64
#  49  S44_real        2350 non-null   float64
#  50  S44_imag        2350 non-null   float64
# dtypes: float64(47), int64(2), object(2)
# memory usage: 936.5+ KB
# None
#
# Valores únicos de altura (H) encontrados:
# [600. 100. 200. 300. 400. 500.]

# %%
altura_desejada = 400.0
df_filt = df_completo.query(f'frequencia_ghz == 281750.0 and H == {altura_desejada}')
df_filt
# Out:
#                       arquivo  \
# 12       Teste_Nanopilar_7.ts
# 22      Teste_Nanopilar_12.ts
# 32      Teste_Nanopilar_17.ts
# 44      Teste_Nanopilar_23.ts
# 56      Teste_Nanopilar_29.ts
# ...                       ...
# 2298  Teste_Nanopilar_1150.ts
# 2310  Teste_Nanopilar_1156.ts
# 2322  Teste_Nanopilar_1162.ts
# 2334  Teste_Nanopilar_1168.ts
# 2346  Teste_Nanopilar_1174.ts
#
#                                                 caminho  id_nanopilar  \
# 12    C:\Users\caval_5gfl5hy\OneDrive\Área de Trabal...             7
# 22    C:\Users\caval_5gfl5hy\OneDrive\Área de Trabal...            12
# 32    C:\Users\caval_5gfl5hy\OneDrive\Área de Trabal...            17
# 44    C:\Users\caval_5gfl5hy\OneDrive\Área de Trabal...            23
# 56    C:\Users\caval_5gfl5hy\OneDrive\Área de Trabal...            29
# ...                                                 ...           ...
# 2298  C:\Users\caval_5gfl5hy\OneDrive\Área de Trabal...          1150
# 2310  C:\Users\caval_5gfl5hy\OneDrive\Área de Trabal...          1156
# 2322  C:\Users\caval_5gfl5hy\OneDrive\Área de Trabal...          1162
# 2334  C:\Users\caval_5gfl5hy\OneDrive\Área de Trabal...          1168
# 2346  C:\Users\caval_5gfl5hy\OneDrive\Área de Trabal...          1174
#
#       frequencia_hz  frequencia_ghz  nports      H    L_x    L_y  Lambda  ...  \
# 12     2.817500e+14        281750.0       4  400.0   70.0   70.0  1064.0  ...
# 22     2.817500e+14        281750.0       4  400.0   70.0   80.0  1064.0  ...
# 32     2.817500e+14        281750.0       4  400.0   70.0   90.0  1064.0  ...
# 44     2.817500e+14        281750.0       4  400.0   70.0  100.0  1064.0  ...
# 56     2.817500e+14        281750.0       4  400.0   70.0  110.0  1064.0  ...
# ...             ...             ...     ...    ...    ...    ...     ...  ...
# 2298   2.817500e+14        281750.0       4  400.0  200.0  160.0  1064.0  ...
# 2310   2.817500e+14        281750.0       4  400.0  200.0  170.0  1064.0  ...
# 2322   2.817500e+14        281750.0       4  400.0  200.0  180.0  1064.0  ...
# 2334   2.817500e+14        281750.0       4  400.0  200.0  190.0  1064.0  ...
# 2346   2.817500e+14        281750.0       4  400.0  200.0  200.0  1064.0  ...
#
#       S34_real  S34_imag  S41_real  S41_imag  S42_real  S42_imag  S43_real  \
# 12    0.000016  0.000015 -0.000075 -0.000082  0.957069  0.000359  0.000023
# 22    0.000208  0.000556  0.000047  0.000261  0.956209 -0.019040  0.000117
# 32   -0.000082 -0.000321 -0.000006 -0.000019  0.956376 -0.040382 -0.000079
# 44    0.000002 -0.000097  0.000075 -0.000203  0.956150 -0.059732 -0.000013
# 56    0.000093 -0.000136 -0.000219 -0.000040  0.955128 -0.079022  0.000095
# ...        ...       ...       ...       ...       ...       ...       ...
# 2298  0.000433 -0.000363  0.000087 -0.000758  0.322898  0.416483  0.000356
# 2310 -0.000023  0.000665 -0.000021  0.001173  0.403782  0.370269 -0.000092
# 2322  0.000574  0.000985 -0.000100  0.001056  0.472139  0.310839  0.000562
# 2334 -0.000217  0.000382  0.000218  0.000260  0.570913  0.262111 -0.000066
# 2346 -0.000508 -0.000498 -0.000555 -0.000696  0.371927  0.216565 -0.000411
#
#       S43_imag  S44_real  S44_imag
# 12    0.000007  0.243786 -0.156655
# 22    0.000574  0.243786 -0.161473
# 32   -0.000317  0.239368 -0.162664
# 44   -0.000137  0.235403 -0.164245
# 56   -0.000135  0.232752 -0.165829
# ...        ...       ...       ...
# 2298 -0.000359  0.544026 -0.652469
# 2310  0.000699  0.453799 -0.702481
# 2322  0.000999  0.351872 -0.745636
# 2334  0.000178  0.252413 -0.735709
# 2346 -0.000706  0.312624 -0.846346
#
# [196 rows x 51 columns]

# %%
cols1 = [
    'id_nanopilar', 
    'L_x', 
    'L_y', 
    'H',
    'frequencia_ghz',
    'S13_real', 
    'S13_imag', 
    'S24_real', 
    'S24_imag'
]
df2 = df_filt[cols1].copy()
df2
# Out:
#       id_nanopilar    L_x    L_y      H  frequencia_ghz  S13_real  S13_imag  \
# 12               7   70.0   70.0  400.0        281750.0  0.957105  0.000377
# 22              12   70.0   80.0  400.0        281750.0  0.955333 -0.055976
# 32              17   70.0   90.0  400.0        281750.0  0.950398 -0.125089
# 44              23   70.0  100.0  400.0        281750.0  0.938405 -0.207969
# 56              29   70.0  110.0  400.0        281750.0  0.914485 -0.307037
# ...            ...    ...    ...    ...             ...       ...       ...
# 2298          1150  200.0  160.0  400.0        281750.0  0.132980  0.627823
# 2310          1156  200.0  170.0  400.0        281750.0  0.370557  0.618685
# 2322          1162  200.0  180.0  400.0        281750.0  0.590030  0.500911
# 2334          1168  200.0  190.0  400.0        281750.0  0.943784 -0.139723
# 2346          1174  200.0  200.0  400.0        281750.0  0.374179  0.217035
#
#       S24_real  S24_imag
# 12    0.957157  0.000350
# 22    0.955999 -0.018778
# 32    0.956294 -0.040286
# 44    0.956137 -0.059781
# 56    0.955084 -0.078965
# ...        ...       ...
# 2298  0.322922  0.416613
# 2310  0.403717  0.370365
# 2322  0.472322  0.310950
# 2334  0.570950  0.262062
# 2346  0.371398  0.216784
#
# [196 rows x 9 columns]

# %%
df2['S_complex_TE'] = df2['S13_real'] + 1j * df2['S13_imag']
df2['S_complex_TM'] = df2['S24_real'] + 1j * df2['S24_imag']

cols2 = ['S13_real', 
    'S13_imag', 
    'S24_real', 
    'S24_imag']
df3 = df2.drop(columns = cols2).copy()
df3.to_csv('df3.csv', index=False)

# %%
print("Carregando a biblioteca de meta-átomos...")
df3 = pd.read_csv('df3.csv')
df3
# Out:
# Carregando a biblioteca de meta-átomos...
#      id_nanopilar    L_x    L_y      H  frequencia_ghz  \
# 0               7   70.0   70.0  400.0        281750.0
# 1              12   70.0   80.0  400.0        281750.0
# 2              17   70.0   90.0  400.0        281750.0
# 3              23   70.0  100.0  400.0        281750.0
# 4              29   70.0  110.0  400.0        281750.0
# ..            ...    ...    ...    ...             ...
# 191          1150  200.0  160.0  400.0        281750.0
# 192          1156  200.0  170.0  400.0        281750.0
# 193          1162  200.0  180.0  400.0        281750.0
# 194          1168  200.0  190.0  400.0        281750.0
# 195          1174  200.0  200.0  400.0        281750.0
#
#                S_complex_TE             S_complex_TM
# 0    (0.957105+0.00037744j)  (0.957157+0.000349566j)
# 1      (0.955333-0.055976j)    (0.955999-0.0187776j)
# 2      (0.950398-0.125089j)    (0.956294-0.0402863j)
# 3      (0.938405-0.207969j)    (0.956137-0.0597807j)
# 4      (0.914485-0.307037j)    (0.955084-0.0789647j)
# ..                      ...                      ...
# 191     (0.13298+0.627823j)     (0.322922+0.416613j)
# 192    (0.370557+0.618685j)     (0.403717+0.370365j)
# 193     (0.59003+0.500911j)      (0.472322+0.31095j)
# 194    (0.943784-0.139723j)      (0.57095+0.262062j)
# 195    (0.374179+0.217035j)     (0.371398+0.216784j)
#
# [196 rows x 7 columns]

# %%
def perform_phase_matching(library_df, target_phase_tm, target_phase_te):
    """
    Executa o algoritmo de casamento de fase para construir a metassuperfície.
    """
    # Extrai os dados da biblioteca em arrays para maior velocidade de processamento
    lib_lx = library_df['L_x'].to_numpy()
    lib_ly = library_df['L_y'].to_numpy()
    lib_H = library_df['H'].to_numpy()
    
    # Mesmo processo anterior, porém converte complexos de strings para números
    lib_S_complex_tm = library_df['S_complex_TM'].to_numpy(dtype=np.complex128)
    lib_S_complex_te = library_df['S_complex_TE'].to_numpy(dtype=np.complex128)
    
    altura, largura = target_phase_tm.shape
    
    # Matrizes para guardar o layout físico e o erro
    layout_lx = np.zeros_like(target_phase_tm, dtype=int)
    layout_ly = np.zeros_like(target_phase_tm, dtype=int)
    layout_H = np.zeros_like(target_phase_tm, dtype=int)
    error_map = np.zeros_like(target_phase_tm, dtype=float)
    
   
    print("\nIniciando busca pelo melhor meta-átomo para cada pixel...")
    for i in tqdm(range(altura), desc="Progresso do Phase Matching"):
        for j in range(largura):
            #Alvos complexos para o pixel (i, j)
            target_tm = np.exp(1j * target_phase_tm[i, j])
            target_te = np.exp(1j * target_phase_te[i, j])
            
            # Calcula o erro quadrático para a biblioteca de uma vez
            error_tm = np.abs(lib_S_complex_tm - target_tm)**2
            error_te = np.abs(lib_S_complex_te - target_te)**2
            total_error = error_tm + error_te
            
            # Encontra o índice do meta-átomo com o menor erro
            best_idx = np.argmin(total_error)
            
            # Armazena a geometria (Lx, Ly) e o erro do melhor candidato
            layout_lx[i, j] = lib_lx[best_idx]
            layout_ly[i, j] = lib_ly[best_idx]
            layout_H[i, j] = lib_H[best_idx]
            error_map[i, j] = total_error[best_idx]
            
    return layout_lx, layout_ly, layout_H, np.sqrt(error_map)

# %%
layout_final_lx, layout_final_ly, layout_final_h, mapa_de_erro_final = perform_phase_matching(
    df3, phase_map_x, phase_map_y)
# Out:
# Iniciando busca pelo melhor meta-átomo para cada pixel...
# Progresso do Phase Matching: 100%|███████████████████████████████████████████████████| 450/450 [00:15<00:00, 29.64it/s]

# %%
plt.figure(figsize=(14, 6))
plt.suptitle("Design Físico Final da Metassuperfície", fontsize=16)

# Plot do mapa de Lx
plt.subplot(1, 2, 1)
im1 = plt.imshow(layout_final_lx, cmap='viridis')
plt.title("Distribuição de L_x")
plt.xlabel("Pixel (coluna)")
plt.ylabel("Pixel (linha)")
plt.colorbar(im1, label="Comprimento Lx (nm)")

# Plot do mapa de Ly
plt.subplot(1, 2, 2)
im2 = plt.imshow(layout_final_ly, cmap='viridis')
plt.title("Distribuição de L_y")
plt.xlabel("Pixel (coluna)")
plt.colorbar(im2, label="Comprimento Ly (nm)")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
plt.figure(figsize=(7, 6))
im_err = plt.imshow(mapa_de_erro_final, cmap='hot')
plt.title("Mapa de Erro do Casamento de Fase")
plt.xlabel("Pixel (coluna)")
plt.ylabel("Pixel (linha)")
plt.colorbar(im_err, label="Erro |E_sim - E_alvo|")
plt.show()

erro_medio = np.mean(mapa_de_erro_final)
print(f"Erro médio final em toda a metassuperfície: {erro_medio:.4f}")
# Out:
# Erro médio final em toda a metassuperfície: 0.7572

# %%
print("Construindo o campo complexo da metassuperfície projetada...")
lookup_table = df3.set_index(['L_x', 'L_y'])['S_complex_TM']

#Matriz para preencher com as propriedades ópticas dos layouts finais
final_phase_map = np.zeros_like(layout_final_lx, dtype=np.complex128)

for i in range(layout_final_lx.shape[0]):
    for j in range(layout_final_lx.shape[1]):
        lx = layout_final_lx[i, j]
        ly = layout_final_ly[i, j]
        final_phase_map[i, j] = lookup_table.loc[(lx, ly)]


print("Propagando o campo para reconstruir a imagem final...")
#Usamos a função do código GS para a reconstrução final
imagem_reconstruida_final = GSx.reconstruct_image(np.angle(final_phase_map), 
                                                  wavelength, z, dx, NA)

plt.figure(figsize=(12, 6))
plt.suptitle("Validação Final da Reconstrução", fontsize=16)

plt.subplot(1, 2, 1)
plt.imshow(target_image, cmap='gray')
plt.title("Imagem Alvo Original")

plt.subplot(1, 2, 2)
plt.imshow(imagem_reconstruida_final, cmap='gray')
plt.title("Imagem Reconstruída a partir do Design Final")

plt.show()

final_correlation = GSx.calculate_correlation(target_image, imagem_reconstruida_final)
print(f"Correlação de Pearson Final: {final_correlation:.4f}")
# Out:
# Construindo o campo complexo da metassuperfície projetada...
# Propagando o campo para reconstruir a imagem final...
# Correlação de Pearson Final: 0.7923

# %%
print("Carregando DataFrame 'df3.csv'...")
df3 = pd.read_csv('df3.csv')
print("Convertendo colunas de texto para números complexos...")
df3['S_complex_TE'] = df3['S_complex_TE'].apply(complex)
df3['S_complex_TM'] = df3['S_complex_TM'].apply(complex)
print("Conversão concluída.")

# --- 1. ADICIONAR FILTRO DE FREQUÊNCIA (CRÍTICO) ---
# Coloque aqui a frequência exata (em GHz) que você está usando.
# Deve ser a MESMA frequência usada para o 'perform_phase_matching'.
freq_alvo_ghz = 27.0  # <--- EXEMPLO. MUDE PARA A SUA FREQUÊNCIA!

print(f"\nFiltrando a biblioteca para a frequência de {freq_alvo_ghz} GHz...")
# Filtra o df3 para conter APENAS os dados da frequência de interesse
df_freq_unica = df3[np.isclose(df3['frequencia_ghz'], freq_alvo_ghz)]

if df_freq_unica.empty:
    print(f"ERRO: Frequência alvo {freq_alvo_ghz} GHz não encontrada em 'df3.csv'")
    # Você pode querer parar o script aqui
    # raise ValueError("Frequência alvo não encontrada na biblioteca.")
else:
    print(f"Biblioteca filtrada com {len(df_freq_unica)} meta-átomos.")


print("\nPreparando para calcular os mapas de erro...")

# --- 2. USAR A CHAVE CORRETA (com H) ---
# Crie a lookup table a partir do DataFrame JÁ FILTRADO
# A chave agora precisa incluir L_x, L_y, e H
lookup_table = df_freq_unica.set_index(['L_x', 'L_y', 'H'])

# (Opcional) Vamos selecionar apenas as colunas que queremos para otimizar
lookup_table = lookup_table[['S_complex_TE', 'S_complex_TM']]

# (Opcional) Se houver duplicatas (mesmo (Lx,Ly,H) na mesma freq), remove
if lookup_table.index.has_duplicates:
    print("Atenção: Duplicatas encontradas no índice, pegando o primeiro valor.")
    lookup_table = lookup_table[~lookup_table.index.duplicated(keep='first')]


altura, largura = layout_final_lx.shape

# Crie as 4 matrizes vazias
phase_error_te_map = np.zeros((altura, largura))
amp_error_te_map = np.zeros((altura, largura))
phase_error_tm_map = np.zeros((altura, largura))
amp_error_tm_map = np.zeros((altura, largura))

print("Calculando os erros para cada pixel...")
for i in tqdm(range(altura), desc="Calculando Mapas de Erro"):
    for j in range(largura):
        # --- 3. USAR A CHAVE COMPLETA (Lx, Ly, H) ---
        # Pegue a geometria escolhida para o pixel (i,j)
        lx = layout_final_lx[i, j]
        ly = layout_final_ly[i, j]
        h = layout_final_h[i, j]  # <--- VOCÊ PRECISA USAR A ALTURA H
        
        try:
            # Busca as propriedades ópticas reais do meta-átomo na biblioteca
            # Use a chave completa (lx, ly, h)
            meta_atomo_escolhido = lookup_table.loc[(lx, ly, h)]
            
            # meta_atomo_escolhido agora é uma Série (linha) 
            # com 'S_complex_TE' e 'S_complex_TM'
            S_te_real = meta_atomo_escolhido['S_complex_TE']
            S_tm_real = meta_atomo_escolhido['S_complex_TM']
            
            # Pega os alvos de fase
            phase_te_alvo = phase_map_y[i, j]
            phase_tm_alvo = phase_map_x[i, j]
            
            # Polarização TE (Dammann)
            phase_error_te_map[i, j] = np.angle(S_te_real / np.exp(1j * phase_te_alvo))
            amp_error_te_map[i, j] = np.abs(S_te_real) - 1.0 # Amplitude alvo é 1
            
            # Polarização TM (Holograma)
            phase_error_tm_map[i, j] = np.angle(S_tm_real / np.exp(1j * phase_tm_alvo))
            amp_error_tm_map[i, j] = np.abs(S_tm_real) - 1.0 # Amplitude alvo é 1
        
        except KeyError:
            # Este 'except' é uma segurança. Se o algoritmo de 'phase_matching'
            # gerou um (lx,ly,h) que não existe na biblioteca (por algum bug),
            # isso evita que o código quebre.
            pass 

print("Cálculos finalizados.")

# --- O RESTO DO SEU CÓDIGO (PLOTS E PRINTS) ESTÁ PERFEITO ---
print("Gerando os gráficos de erro...")
fig, axes = plt.subplots(2, 2, figsize=(10, 9))
# ... (etc)
# (Seu código de plotagem continua aqui, sem alterações)
# ...
fig.suptitle("Mapas de Erro da Metassuperfície", fontsize=16)


im_a = axes[0, 0].imshow(np.abs(phase_error_te_map), cmap='jet', vmin=0, vmax=0.5)
axes[0, 0].set_title("Phase error (TE)")
fig.colorbar(im_a, ax=axes[0, 0], label="Erro de Fase (rad)")


im_b = axes[0, 1].imshow(amp_error_te_map, cmap='jet', vmin=-0.35, vmax=0)
axes[0, 1].set_title("Amplitude error (TE)")
fig.colorbar(im_b, ax=axes[0, 1], label="Erro de Amplitude")


im_c = axes[1, 0].imshow(np.abs(phase_error_tm_map), cmap='jet', vmin=0, vmax=0.5)
axes[1, 0].set_title("Phase error (TM)")
fig.colorbar(im_c, ax=axes[1, 0], label="Erro de Fase (rad)")


im_d = axes[1, 1].imshow(amp_error_tm_map, cmap='jet', vmin=-0.35, vmax=0)
axes[1, 1].set_title("Amplitude error (TM)")
fig.colorbar(im_d, ax=axes[1, 1], label="Erro de Amplitude")

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

#Erro médio das fases
erro_medio_fase_abs_tm = np.mean(np.abs(phase_error_tm_map))
erro_medio_fase_abs_te = np.mean(np.abs(phase_error_te_map))

#Erro médio das amplitudes
erro_medio_amp_abs_tm = np.mean(np.abs(amp_error_tm_map))
erro_medio_amp_abs_te = np.mean(np.abs(amp_error_te_map))

#Resultados printados
print(f"\nO erro médio de fase absoluto (TM - Holograma) foi: {erro_medio_fase_abs_tm:.4f} rad")

print(f"O erro médio de fase absoluto (TE - Dammann) foi: {erro_medio_fase_abs_te:.4f} rad")

print(f"(Valor do artigo para comparação: Erro Fase ~0.094 rad)")

print(f"\nO erro médio de amplitude absoluto (TM - Holograma) foi: {erro_medio_amp_abs_tm:.4f}")

print(f"O erro médio de amplitude absoluto (TE - Dammann) foi: {erro_medio_amp_abs_te:.4f}")

print(f"(Valor do artigo para comparação: Erro Amplitude ~0.015 por pixel)")
# Out:
# Carregando DataFrame 'df3.csv'...
# Convertendo colunas de texto para números complexos...
# Conversão concluída.
#
# Filtrando a biblioteca para a frequência de 27.0 GHz...
# ERRO: Frequência alvo 27.0 GHz não encontrada em 'df3.csv'
#
# Preparando para calcular os mapas de erro...
# Calculando os erros para cada pixel...
# Calculando Mapas de Erro: 100%|██████████████████████████████████████████████████████| 450/450 [00:24<00:00, 18.51it/s]
# Cálculos finalizados.
# Gerando os gráficos de erro...
# O erro médio de fase absoluto (TM - Holograma) foi: 0.0000 rad
# O erro médio de fase absoluto (TE - Dammann) foi: 0.0000 rad
# (Valor do artigo para comparação: Erro Fase ~0.094 rad)
#
# O erro médio de amplitude absoluto (TM - Holograma) foi: 0.0000
# O erro médio de amplitude absoluto (TE - Dammann) foi: 0.0000
# (Valor do artigo para comparação: Erro Amplitude ~0.015 por pixel)

# %%
lookup_table.to_csv('lookup_table.csv', index=False)
df6 = pd.read_csv('lookup_table.csv')
df6
# Out:
# Empty DataFrame
# Columns: [S_complex_TE, S_complex_TM]
# Index: []

# %%
# --- Passo 1: Criar um DataFrame de exemplo ---
# (Esta parte é apenas para que o código possa ser executado. 
# O seu DataFrame 'lookup_table' real será usado no seu projeto.)

print("Criando um DataFrame de exemplo chamado 'lookup_table'...")
dados_exemplo = {
    'Lx': np.arange(70, 75),
    'Ly': np.arange(80, 85),
    'fase': np.random.rand(5) * np.pi
}
lookup_table = pd.DataFrame(dados_exemplo)
print("DataFrame original:")
print(lookup_table)
print("\n" + "="*40 + "\n")


# --- Passo 2: O seu código para salvar e ler ---

# Salva o DataFrame no arquivo 'lookup_table.csv'
# O arquivo será criado na mesma pasta onde seu script/notebook está.
print("Salvando o DataFrame em 'lookup_table.csv'...")
lookup_table.to_csv('lookup_table.csv', index=False)
print("Arquivo salvo com sucesso!")

# Lê o arquivo CSV que acabou de ser salvo para um novo DataFrame
print("Lendo o arquivo de volta para a variável 'df6'...")
df6 = pd.read_csv('lookup_table.csv')

# Exibe o conteúdo do novo DataFrame para verificar
print("\nConteúdo do DataFrame 'df6' (lido do arquivo):")
print(df6)
# Out:
# Criando um DataFrame de exemplo chamado 'lookup_table'...
# DataFrame original:
#    Lx  Ly      fase
# 0  70  80  1.100192
# 1  71  81  0.841911
# 2  72  82  0.194431
# 3  73  83  2.580201
# 4  74  84  1.192757
#
# ========================================
#
# Salvando o DataFrame em 'lookup_table.csv'...
# Arquivo salvo com sucesso!
# Lendo o arquivo de volta para a variável 'df6'...
#
# Conteúdo do DataFrame 'df6' (lido do arquivo):
#    Lx  Ly      fase
# 0  70  80  1.100192
# 1  71  81  0.841911
# 2  72  82  0.194431
# 3  73  83  2.580201
# 4  74  84  1.192757

# %%
# --- Supondo que essas variáveis já existem no seu código ---
# layout_final_lx: Matriz com as dimensões Lx para cada pixel
# layout_final_ly: Matriz com as dimensões Ly para cada pixel
# df5: Seu DataFrame original com a lookup table
# GSx, target_image, wavelength, z, dx, NA, plt: Outras variáveis e módulos necessários

# ==============================================================================
# 1. Construir o campo complexo E SALVAR OS DADOS DA METASUPERFÍCIE
print("Construindo o campo complexo e mapeando a metassuperfície...")
# Converte a coluna de string para o tipo de dado complexo
df5['S_complex_TM'] = df5['S_complex_TM'].apply(complex)
# Crie um dicionário para busca rápida (lookup)
lookup_table = df5.set_index(['L_x', 'L_y'])['S_complex_TM']

# Inicializa o mapa de fase final
final_phase_map = np.zeros_like(layout_final_lx, dtype=np.complex128)

# Lista para armazenar os dados de cada nanopilar para o CSV
dados_metasuperficie = []

# O laço for que monta a metassuperfície
for i in range(layout_final_lx.shape[0]):
    for j in range(layout_final_lx.shape[1]):
        lx = layout_final_lx[i, j]
        ly = layout_final_ly[i, j]
        
        # Busca o campo complexo na lookup table
        campo_complexo = lookup_table.loc[(lx, ly)]
        
        # Atribui o valor ao mapa final
        final_phase_map[i, j] = campo_complexo
        
        # Adiciona os dados deste pixel (nanopilar) à nossa lista
        dados_metasuperficie.append({
            'pos_i': i,               # Coordenada da linha
            'pos_j': j,               # Coordenada da coluna
            'Lx_nm': lx,              # Dimensão Lx em nanômetros
            'Ly_nm': ly,              # Dimensão Ly em nanômetros
            'fase_rad': np.angle(campo_complexo),    # Fase em radianos
            'amplitude': np.abs(campo_complexo)      # Amplitude (transmitância)
        })

# Converte a lista de dados em um DataFrame do Pandas
df_metasuperficie_final = pd.DataFrame(dados_metasuperficie)

# Salva o DataFrame em um arquivo CSV
caminho_arquivo_csv = 'design_metasuperficie_para_CST.csv'
df_metasuperficie_final.to_csv(caminho_arquivo_csv, index=False)

print(f"\nDados da metassuperfície salvos com sucesso em: '{caminho_arquivo_csv}'")
print("O arquivo contém as coordenadas e dimensões de cada nanopilar.")
print("\nDataFrame gerado:")
print(df_metasuperficie_final.head()) # Mostra as 5 primeiras linhas
# ==============================================================================


# 2. Reconstruir a imagem a partir deste novo mapa de fase
print("\nPropagando o campo para reconstruir a imagem final...")
imagem_reconstruida_final = GSx.reconstruct_image(np.angle(final_phase_map), 
                                                  wavelength, z, dx, NA)

import matplotlib.pyplot as plt
import numpy as np # Adicionado para criar imagens de exemplo

if 'target_image' not in locals():
    print("Criando imagem alvo de exemplo...")
    target_image = np.zeros((100, 100))
    target_image[25:75, 25:75] = 1 # Um quadrado como alvo
if 'final_phase_map' not in locals():
     final_phase_map = np.random.rand(100,100) * 2 * np.pi

# 2. Reconstruir a imagem a partir deste novo mapa de fase
print("\nPropagando o campo para reconstruir a imagem final...")
# No seu código, esta função virá do seu módulo GSx
def reconstruct_image_placeholder(phase_map, *args):
    # Esta é uma simulação simples da reconstrução para o exemplo
    reconstructed = np.abs(np.fft.ifft2(np.exp(1j * phase_map)))
    reconstructed = np.fft.fftshift(reconstructed)
    return reconstructed

if 'GSx' not in locals() or not hasattr(GSx, 'reconstruct_image'):
    print("Usando função de reconstrução de exemplo...")
    imagem_reconstruida_final = reconstruct_image_placeholder(np.angle(final_phase_map))
else:
    imagem_reconstruida_final = GSx.reconstruct_image(np.angle(final_phase_map), 
                                                      wavelength, z, dx, NA)
                                                      
# ==============================================================================
# 3. PLOTAR E COMPARAR AS IMAGENS (A parte que você pediu)
# ==============================================================================
print("Gerando gráfico de comparação...")

plt.figure(figsize=(12, 6))
plt.suptitle("Comparação da Imagem Alvo vs. Reconstruída", fontsize=16)

# Subplot 1: Imagem Alvo Original
plt.subplot(1, 2, 1)
plt.imshow(target_image, cmap='gray')
plt.title("Imagem Alvo Original")
plt.axis('off') # Remove os eixos para uma visualização mais limpa

# Subplot 2: Imagem Reconstruída
plt.subplot(1, 2, 2)
plt.imshow(imagem_reconstruida_final, cmap='gray')
plt.title("Imagem Reconstruída do Design Final")
plt.axis('off') # Remove os eixos

# Ajusta o layout para evitar sobreposição de títulos e mostra o gráfico
plt.tight_layout(rect=[0, 0, 1, 0.96]) # Ajusta para o suptitle
plt.savefig("reconstrucao_final.png") # Salva a figura em um arquivo
plt.show()

# Opcional: Calcular a correlação (Figure of Merit - FoM)
if 'GSx' in locals() and hasattr(GSx, 'calculate_correlation'):
    final_correlation = GSx.calculate_correlation(target_image, imagem_reconstruida_final)
    print(f"\nCorrelação de Pearson Final: {final_correlation:.4f}")
# Out:
# Construindo o campo complexo e mapeando a metassuperfície...
#
# Dados da metassuperfície salvos com sucesso em: 'design_metasuperficie_para_CST.csv'
# O arquivo contém as coordenadas e dimensões de cada nanopilar.
#
# DataFrame gerado:
#    pos_i  pos_j  Lx_nm  Ly_nm  fase_rad  amplitude
# 0      0      0    145    100  0.918672   0.980559
# 1      0      1    170     70  1.536964   0.955150
# 2      0      2    130    105  1.970898   0.962530
# 3      0      3    120    105  2.881670   0.946326
# 4      0      4    125     85 -2.992262   0.955253
#
# Propagando o campo para reconstruir a imagem final...
#
# Propagando o campo para reconstruir a imagem final...
# Gerando gráfico de comparação...
# Correlação de Pearson Final: 0.8031

# %%
import numpy as np
import pandas as pd
from scipy.spatial import KDTree
import matplotlib.pyplot as plt

# --- Supondo que suas variáveis iniciais já existem ---
# df5, layout_final_lx, layout_final_ly, etc.

# ==============================================================================
# 1. PREPARAR A BIBLIOTECA E MONTAR A METASUPERFÍCIE
# ==============================================================================

print("Preparando a biblioteca de nanopilares para busca otimizada...")
# Extrai as coordenadas (Lx, Ly) da sua biblioteca
biblioteca_pontos = df5[['L_x', 'L_y']].values
# Cria a árvore de busca para encontrar pontos próximos de forma eficiente
kdtree = KDTree(biblioteca_pontos)

# Mantém o df5 com índice para pegar os valores complexos depois
df5_indexed = df5.set_index(['L_x', 'L_y'])

# Inicializa o mapa de fase final
final_phase_map = np.zeros_like(layout_final_lx, dtype=np.complex128)

# >>> INÍCIO DA PARTE DE SALVAR O CSV <<<
# Lista para armazenar os dados de cada nanopilar
dados_metasuperficie = []
print("Construindo o campo complexo e mapeando a metassuperfície para o CSV...")

for i in range(layout_final_lx.shape[0]):
    for j in range(layout_final_lx.shape[1]):
        # Ponto (geometria) desejado pelo algoritmo de otimização
        lx_desejado = layout_final_lx[i, j]
        ly_desejado = layout_final_ly[i, j]
        ponto_desejado = (lx_desejado, ly_desejado)

        # Busca na KDTree pelo ponto mais próximo que existe na sua biblioteca
        distancia, indice_proximo = kdtree.query(ponto_desejado)
        
        # Pega as dimensões (Lx, Ly) do ponto real encontrado
        lx_real = biblioteca_pontos[indice_proximo][0]
        ly_real = biblioteca_pontos[indice_proximo][1]
        
        # Usa essas dimensões reais para buscar o campo complexo
        campo_complexo = df5_indexed.loc[(lx_real, ly_real)]['S_complex_TM']
        final_phase_map[i, j] = campo_complexo
        
        # Adiciona todas as informações à nossa lista para o CSV
        dados_metasuperficie.append({
            'pos_i': i,
            'pos_j': j,
            'Lx_desejado_nm': lx_desejado, # O que o algoritmo queria
            'Ly_desejado_nm': ly_desejado, # O que o algoritmo queria
            'Lx_real_nm': lx_real,         # O que foi usado da biblioteca
            'Ly_real_nm': ly_real,         # O que foi usado da biblioteca
            'fase_rad': np.angle(campo_complexo),
            'amplitude': np.abs(campo_complexo)
        })

# >>> FIM DA PARTE DE SALVAR O CSV <<<

# Converte a lista de dados em um DataFrame
df_metasuperficie_final = pd.DataFrame(dados_metasuperficie)

# Salva o DataFrame em um arquivo CSV
caminho_arquivo_csv = 'design_metasuperficie_com_kdtree.csv'
df_metasuperficie_final.to_csv(caminho_arquivo_csv, index=False)

print(f"\nDados da metassuperfície salvos com sucesso em: '{caminho_arquivo_csv}'")
print("\nDataFrame gerado:")
print(df_metasuperficie_final.head()) # Mostra as 5 primeiras linhas do arquivo


# ==============================================================================
# 2. RECONSTRUÇÃO E PLOTAGEM (continua igual)
# ==============================================================================

# ... (seu código para reconstruir a imagem com GSx.reconstruct_image) ...
# ... (seu código para plotar as imagens lado a lado) ...
# Out:
# Preparando a biblioteca de nanopilares para busca otimizada...
# Construindo o campo complexo e mapeando a metassuperfície para o CSV...
#
# Dados da metassuperfície salvos com sucesso em: 'design_metasuperficie_com_kdtree.csv'
#
# DataFrame gerado:
#    pos_i  pos_j  Lx_desejado_nm  Ly_desejado_nm  Lx_real_nm  Ly_real_nm  \
# 0      0      0             145             100         145         100
# 1      0      1             170              70         170          70
# 2      0      2             130             105         130         105
# 3      0      3             120             105         120         105
# 4      0      4             125              85         125          85
#
#    fase_rad  amplitude
# 0  0.918672   0.980559
# 1  1.536964   0.955150
# 2  1.970898   0.962530
# 3  2.881670   0.946326
# 4 -2.992262   0.955253

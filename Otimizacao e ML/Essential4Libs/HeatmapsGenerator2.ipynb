ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_847.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_848.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_849.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_850.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_851.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_852.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_853.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_854.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_855.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_856.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_857.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_858.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_859.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_860.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_861.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_862.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_863.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_864.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_865.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_866.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_867.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_868.ts (ID:2)...
# Lendo arquivo: 2_Teste_Nanopilar_869.ts (ID:2)...

# %%
df_filt1064nm = df.query('frequencia_ghz == 281760.0')
df2 = df_filt1064nm.drop(['id_nanopilar'], axis =1)

inicio = 70
fim = 200
passo = 5.2

valores = np.arange(inicio, fim + 1, passo)

print(f"Valores base: {valores}")
num_valores = len(valores)
print(f"Número de valores únicos: {num_valores}")
print(f"Tamanho total da matriz será: {num_valores} x {num_valores} = {num_valores**2}")

coluna1 = np.repeat(valores, repeats=num_valores)

coluna2 = np.tile(valores, reps=num_valores)

matriz = np.column_stack((coluna1, coluna2))

df3 = df2.sort_values(by='arquivo')
df3['L_x'] = matriz[:, 0]
df3['L_y'] = matriz[:, 1]

df3
# Out:
# Valores base: [ 70.   75.2  80.4  85.6  90.8  96.  101.2 106.4 111.6 116.8 122.  127.2
#  132.4 137.6 142.8 148.  153.2 158.4 163.6 168.8 174.  179.2 184.4 189.6
#  194.8 200. ]
# Número de valores únicos: 26
# Tamanho total da matriz será: 26 x 26 = 676
#                          arquivo  frequencia_hz  frequencia_ghz  S11_real  \
# 600       2_Teste_Nanopilar_1.ts   2.817600e+14        281760.0  0.217917
# 1601    2_Teste_Nanopilar_197.ts   2.817600e+14        281760.0  0.218770
# 2602    2_Teste_Nanopilar_198.ts   2.817600e+14        281760.0  0.218712
# 3603    2_Teste_Nanopilar_199.ts   2.817600e+14        281760.0  0.216971
# 4604    2_Teste_Nanopilar_200.ts   2.817600e+14        281760.0  0.214583
# ...                          ...            ...             ...       ...
# 672271  2_Teste_Nanopilar_865.ts   2.817600e+14        281760.0  0.350900
# 673272  2_Teste_Nanopilar_866.ts   2.817600e+14        281760.0  0.389630
# 674273  2_Teste_Nanopilar_867.ts   2.817600e+14        281760.0  0.429652
# 675274  2_Teste_Nanopilar_868.ts   2.817600e+14        281760.0  0.465692
# 676275  2_Teste_Nanopilar_869.ts   2.817600e+14        281760.0  0.501877
#
#         S11_imag  S12_real  S12_imag  S13_real  S13_imag  S14_real  ...  \
# 600    -0.027912 -0.000058  0.000072  0.295332 -0.929767  0.000132  ...
# 1601   -0.038217  0.000026 -0.000107  0.251353 -0.942063  0.000026  ...
# 2602   -0.049619 -0.000052 -0.000115  0.203460 -0.953033 -0.000148  ...
# 3603   -0.062645 -0.000032  0.000016  0.147090 -0.962835 -0.000043  ...
# 4604   -0.077445  0.000158  0.000014  0.083955 -0.970345 -0.000196  ...
# ...          ...       ...       ...       ...       ...       ...  ...
# 672271  0.269191  0.000226 -0.000328  0.405195 -0.800314  0.000070  ...
# 673272  0.256053  0.000021  0.000035  0.336517 -0.818149  0.000141  ...
# 674273  0.241603  0.000157  0.000005  0.265388 -0.828574  0.000056  ...
# 675274  0.222183  0.000189  0.000111  0.200991 -0.832634 -0.000176  ...
# 676275  0.200537 -0.000220 -0.000236  0.133881 -0.830622 -0.000174  ...
#
#         S41_real  S41_imag  S42_real  S42_imag  S43_real  S43_imag  S44_real  \
# 600     0.000082  0.000117  0.295042 -0.929984 -0.000027 -0.000030  0.161945
# 1601    0.000191  0.000094  0.278894 -0.934774  0.000005  0.000191  0.165053
# 2602   -0.000169 -0.000002  0.264026 -0.938848 -0.000116 -0.000047  0.167974
# 3603    0.000178 -0.000065  0.248095 -0.943042 -0.000174  0.000107  0.170683
# 4604   -0.000213 -0.000097  0.233169 -0.946632  0.000150 -0.000159  0.173746
# ...          ...       ...       ...       ...       ...       ...       ...
# 672271  0.000250 -0.000114  0.126211 -0.923611 -0.000058  0.000312  0.361749
# 673272  0.000160 -0.000086  0.359470 -0.430208 -0.000235  0.000138  0.757723
# 674273  0.000230  0.000190  0.221958 -0.794806  0.000099  0.000320  0.564202
# 675274 -0.000072  0.000202  0.170074 -0.822647  0.000223 -0.000132  0.542632
# 676275 -0.000259 -0.000123  0.135149 -0.831221 -0.000158 -0.000064  0.538251
#
#         S44_imag    L_x    L_y
# 600     0.148128   70.0   70.0
# 1601    0.145776   70.0   75.2
# 2602    0.143598   70.0   80.4
# 3603    0.141300   70.0   85.6
# 4604    0.139558   70.0   90.8
# ...          ...    ...    ...
# 672271  0.001844  200.0  179.2
# 673272  0.333887  200.0  184.4
# 674273  0.028035  200.0  189.6
# 675274 -0.006296  200.0  194.8
# 676275 -0.031117  200.0  200.0
#
# [676 rows x 37 columns]

# %%
colunas = ['arquivo', 'frequencia_hz', 'frequencia_ghz', 'S13_real', 'S13_imag', 'L_x', 'L_y']
df_TE = df3[colunas].copy()
df_TE['fase'] = np.arctan2(df_TE['S13_imag'], df_TE['S13_real'])
df_TE['transmitancia'] = np.sqrt((df_TE['S13_imag'])**2 + (df_TE['S13_real'])**2)
df_TE['L_x'] = df_TE['L_x'].round(1)
df_TE['L_y'] = df_TE['L_y'].round(1)
df_pivot = df_TE.pivot(index='L_y', columns='L_x', values='fase')
df_pivot2 = df_TE.pivot(index='L_y', columns='L_x', values='transmitancia')

colunas2 = ['arquivo', 'frequencia_hz', 'frequencia_ghz', 'S24_real', 'S24_imag', 'L_x', 'L_y']
df_TM = df3[colunas2].copy()
df_TM['fase'] = np.arctan2(df_TM['S24_imag'], df_TM['S24_real'])
df_TM['transmitancia'] = np.sqrt((df_TM['S24_imag'])**2 + (df_TM['S24_real'])**2)
df_TM['L_x'] = df_TM['L_x'].round(1)
df_TM['L_y'] = df_TM['L_y'].round(1)
df_pivot3 = df_TM.pivot(index='L_y', columns='L_x', values='transmitancia')
df_pivot4 = df_TM.pivot(index='L_y', columns='L_x', values='fase')

# %%
plt.figure(figsize=(8, 6))
ax = sns.heatmap(
    df_pivot, 
    annot=False, 
    fmt=".2f", 
    cmap='jet',
    vmin=-np.pi,  
    vmax=np.pi,
    linewidths=0.5,
    linecolor='black',
    cbar_kws={'ticks': [-np.pi, -np.pi/2, 0, np.pi/2, np.pi]} 
)
colorbar = ax.collections[0].colorbar
colorbar.set_ticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])

plt.title('Phase TE', fontsize=16)
plt.xlabel('L_x (nm)', fontsize=12)
plt.ylabel('L_y (nm)', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    df_pivot2, 
    annot=False, 
    fmt=".2f", 
    cmap='jet',
    vmin=0.7,                                  
    vmax=1.0,
    linewidths=0.5,
    linecolor='black',
    cbar_kws={'ticks': [0.7, 0.8, 0.9, 1.0]})

plt.title('Transmittance TE', fontsize=16)
plt.xlabel('L_x (nm)', fontsize=12)
plt.ylabel('L_y (nm)', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    df_pivot3, 
    annot=False, 
    fmt=".2f", 
    cmap='jet',
    vmin=0.7,                                  
    vmax=1.0,
    linewidths=0.5,
    linecolor='black',
    cbar_kws={'ticks': [0.7, 0.8, 0.9, 1.0]})
plt.title('Transmittance TM', fontsize=16)
plt.xlabel('L_x (nm)', fontsize=12)
plt.ylabel('L_y (nm)', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.heatmap(
    df_pivot4, 
    annot=False, 
    fmt=".2f", 
    cmap='jet',
    vmin=-np.pi,  
    vmax=np.pi,
    linewidths=0.5,
    linecolor='black',
    cbar_kws={'ticks': [-np.pi, -np.pi/2, 0, np.pi/2, np.pi]})
colorbar = ax.collections[0].colorbar
colorbar.set_ticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
plt.title('Phase TM', fontsize=16)
plt.xlabel('L_x', fontsize=12)
plt.ylabel('L_y', fontsize=12)
plt.show()

# %%
# Out:
# Collecting scikit-rf
#   Obtaining dependency information for scikit-rf from https://files.pythonhosted.org/packages/be/e5/a9683c068dfe3121d5e131dadc40d1fb071ce32f0979df3f8a00e768514b/scikit_rf-1.8.0-py3-none-any.whl.metadata
#   Downloading scikit_rf-1.8.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\caval_5gfl5hy\anaconda3\lib\site-packages (from scikit-rf) (1.24.3)
# Requirement already satisfied: scipy>=1.7 in c:\users\caval_5gfl5hy\anaconda3\lib\site-packages (from scikit-rf) (1.11.1)
# Requirement already satisfied: pandas>=1.1 in c:\users\caval_5gfl5hy\anaconda3\lib\site-packages (from scikit-rf) (2.0.3)
# Requirement already satisfied: typing-extensions in c:\users\caval_5gfl5hy\anaconda3\lib\site-packages (from scikit-rf) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\caval_5gfl5hy\anaconda3\lib\site-packages (from pandas>=1.1->scikit-rf) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\caval_5gfl5hy\anaconda3\lib\site-packages (from pandas>=1.1->scikit-rf) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\caval_5gfl5hy\anaconda3\lib\site-packages (from pandas>=1.1->scikit-rf) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\caval_5gfl5hy\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1->scikit-rf) (1.16.0)
# Downloading scikit_rf-1.8.0-py3-none-any.whl (617 kB)
#    ---------------------------------------- 0.0/617.1 kB ? eta -:--:--
#    ------ --------------------------------- 102.4/617.1 kB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  614.4/617.1 kB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 617.1/617.1 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: scikit-rf
# Successfully installed scikit-rf-1.8.0
